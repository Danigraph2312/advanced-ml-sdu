# %% [markdown]
# # Project 1 - Cat & Dog Classification
# ## Introduction
#
# The assigned project involves the modeling and the succeeding training of a deep neural network on a dataset composed of images of cats and dogs in order to discriminate one from the other: indeed, the problem we are facing a binary classification problem.
# The nature of the input is an image on: each image of the training, evaluation and test dataset has size [3, 150, 150].
# In order to measure the success, so the efficiency, of the model, we decided to use the confusion matrix that counts the occurrences of predictions based on true values:
#
#
# |                 | Predicted: Dog | Predicted: Cat |
# |-----------------|----------------|----------------|
# | **Actual: Dog** | $n_{dd}$       | $n_{dc}$       |
# | **Actual: Cat** | $n_{cd}$       | $n_{cc}$       |
#
# where the number of observations of class  for which class  was predicted:
#
# $$
# n_{kl}= \sum_{i=1}^{n}{(Y_i=k \quad \text{and} \quad \hat{Y}_i=l)} \qquad \quad  k, l \in \{\text{cat}, \text{dog}\}
# $$
# where:
# -   $n$: number of observation (in this context, number of image);
#
# -   $k$: true values;
#
# -   $l$: predicted class.
# In the specific case of the binary classification, in which the categorical variable has only two modalities (cat and dog), the values in the confusion matrix would be:
#
# -   $n_{dd}$ and $n_{cc}$: right prediction —\> classified correctly;
#
# -   $n_{dc}$ and $n_{cd}$ wrong prediction —\> mis-classification.
#
# Each image in the training, validation, and test data sets has dimensions of **[3, 150, 150]**, where:
#
# -   The first dimension represents the number of color channels (RGB);
#
# -   The remaining two dimensions define the height and width of the images.
#
# To assess the model's performance, we utilize a **confusion matrix**, which records the number of correct and incorrect predictions based on the true class labels.

# %% [markdown]
# ## Data Loading and Augmentation
#
# The work begins with **data loading** subdivided in training, evaluation and test data on which to run the network using a **data-loader** because of the high dimension and of the pixel nature of the input. Using the data loader on data set, it’s useful because it will apply the transformations to all images in the batch it loads; Therefore, every time it load the same image, it will be different versions of it. To effectively train the neural network, we partition the data set into three subsets:\
# - **Training set** – Used to train the model.\
# - **Validation set** – Used to fine-tune hyper parameters and prevent over fitting.\
# - **Test set** – Used to evaluate the final model's generalization capability.
#
# In order to make the model as efficient as possible and being able to predict the true class, **data augmentation** techniques are used such that even a little modification of the image doesn’t affect the result of the model and also to allow a more and better generalization of the model. For a classification task it’s easier because the goal of a classifier is to be invariant to a wide variety of transformations: we can generate new   pairs easily just by transforming the inputs in our training set. In the case of the project, for the training data we tried different transformations and after different experiments, we opted for:
#
# -   A **rotation** of the input data of 15 degrees;
#
# -   A **zoom** between 80% and 120%;
#
# -   An **horizontal flip**.
#
# Regarding the validation and test data, these, along with the training input after data augmentation, are subject to image resizing to the original size in order to correctly perform calculation in the model and a normalization of all data.
#
# After analysis, we confirmed that the training (2,000 images), validation (600 images), and test (400 images) sets are evenly distributed between cats and dogs.

# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import seaborn as sns
import matplotlib.pyplot as plt

# Define transformations:convert to tensor
transform_train = transforms.Compose([
    transforms.RandomAffine(degrees = 15, scale = (0.8, 1.2)), # rotate of 15 degrees and zoom from 80 to 120%
    transforms.RandomHorizontalFlip(),
    transforms.Resize((150, 150)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

transform = transforms.Compose([
    transforms.Resize((150, 150)),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load train dataset
train_dataset = datasets.ImageFolder(root="/Users/dmensorio/Desktop/Università Daniele/Third Year/AI506 - Advanced Machine Learning/projects/project 1/catdog_data/train", 
                                    transform=transform_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Load test dataset
test_dataset = datasets.ImageFolder(root="/Users/dmensorio/Desktop/Università Daniele/Third Year/AI506 - Advanced Machine Learning/projects/project 1/catdog_data/test", 
                                    transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Load validation dataset
val_dataset = datasets.ImageFolder(root="/Users/dmensorio/Desktop/Università Daniele/Third Year/AI506 - Advanced Machine Learning/projects/project 1/catdog_data/validation", 
                                    transform=transform)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)

# Check class mapping
print(train_dataset.class_to_idx)  # {'cats': 0, 'dogs': 1}

image, label = train_dataset[0]
# Check the size of the image
print("Image Size:", image.shape)
#check the label
print(train_dataset.classes) 
print(train_dataset.class_to_idx)
# Out:
# {'cats': 0, 'dogs': 1}
# Image Size: torch.Size([3, 150, 150])
# ['cats', 'dogs']
# {'cats': 0, 'dogs': 1}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fix for dataset size and distribution plot
print(f"Train dataset size: {len(train_dataset)}, Test dataset size: {len(test_dataset)}, Validation dataset size: {len(val_dataset)}")

def plot_class_distribution(dataset):
    labels = np.array(dataset.targets)  # Convert list to numpy array
    plt.hist(labels, bins=np.arange(len(dataset.classes) + 1) - 0.5, edgecolor='black', alpha=0.7)
    plt.xticks(range(len(dataset.classes)), dataset.classes)
    plt.xlabel("Class Label")
    plt.ylabel("Count")
    plt.title("Class Distribution in Dataset")
    plt.show()

plot_class_distribution(train_dataset)
plot_class_distribution(test_dataset)
plot_class_distribution(val_dataset)
# Out:
# Train dataset size: 2000, Test dataset size: 400, Validation dataset size: 600

# %% [markdown]
# ## Model Definition
#
# Since the input data is made of grid-like topology (image), we choose to implement a **Convolutional Neural Network** (CNN), instead of a deep feedforward neural network, for this binary image classification. This CNN model is made of :
#
# -   two **constitutional layers**: each constitutional layer has a kernel size of 3x3 with padding 1 that is used to maintain the dimension of the original data;
#
# -   a **pooling layer**: in this model, we could decide, depending on performance and result, to use an Average Polling or a Max Pooling layer with different window size (different kernel and stride size) ;
#
# -   Two **Fully Connected layers**: the first FC layer transform the feature maps into a 128-dimensional representation, the second one, instead, maps this to two output neurons, one for each class of the problem (cat or dog);
#
# -   A **dropout layer** (if employed: it will be discussed successively): added before the first fully connected layer in order to prevent data over-fitting, randomly disabling neurons during training; a dropout rate could be chosen;
#
# -   A **ReLU activation function**: it is applied after constitutional and fully connected layers to introduce non-linearity in the model.

# %%
# Define the CNN model
class CNN(nn.Module):
    def __init__(self, dropout_rate=0.1, pool_type="max", pool_kernel=2, pool_stride=2):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)

        if pool_type == "max":
            self.pool = nn.MaxPool2d(kernel_size=pool_kernel, stride=pool_stride)
        elif pool_type == "avg":
            self.pool = nn.AvgPool2d(kernel_size=pool_kernel, stride=pool_stride)
        else:
            print("choose between max and avg pooling!")

        # Fully connected layers
        if pool_kernel == 2 and pool_stride == 2:
            self.fc1 = nn.Linear(64 * 37 * 37, 128)
        elif pool_kernel ==3 and pool_stride == 2:
            self.fc1 = nn.Linear(64 * 36 * 36, 128)
        elif pool_kernel == 3 and pool_stride == 3:
            self.fc1 = nn.Linear(64 * 16 * 16, 128)
        self.dropout = nn.Dropout(p=dropout_rate)
        self.fc2 = nn.Linear(128, 2)  # 2 output classes (cats & dogs)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)  # Flatten
        x = self.dropout(x)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Train the CNN Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#trying different pooling layers
model = CNN().to(device) #with max pooling
model_w_avgpool = CNN(pool_type="avg").to(device) # with avergaing pooling
model_w_3x2kmaxpool = CNN(pool_kernel=3, pool_stride=2).to(device) # with max pooling with kernel 3 and stride 2
model_w_3x3kmaxpool = CNN(pool_kernel=3, pool_stride=3).to(device) # with max pooling with kernel 3 and stride 3

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005) #already tried with 0.001 maybe too high. trying with 0.0005

best_loss=float('inf')
epochs_without_improvement=0

def train_model(model, train_loader, val_loader, criterion, optimizer, epochs=5, patience=3, regularization_type, lambda_val=0.01):
    train_losses = []  
    val_losses = []  
    val_accuracies = []   
    best_loss = float('inf')  
    epochs_without_improvement = 0  
    model.train()

    for epoch in range(epochs):
        running_loss = 0.0
        model.train()
        
        # Training 
        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()  
            outputs = model(images)
            loss = criterion(outputs, labels) 

            # Regularization
            if regularization_type == 'L1':
                l1_reg = lambda_val * torch.norm(model.fc2.weight, 1)
                loss += l1_reg
            elif regularization_type == 'L2':
                l2_reg = lambda_val * torch.norm(model.fc2.weight, 2)
                loss += l2_reg
        
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_losses.append(running_loss / len(train_loader))  

        # Evaluation
        model.eval()
        correct = 0
        total = 0
        val_loss = 0.0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)

                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        val_accuracies.append(100 * correct / total)

        print(f'Epoch {epoch+1}, Training Loss: {train_losses[-1]:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracies[-1]:.2f}%')

        # Early stopping
        if avg_val_loss < best_loss:
            best_loss = avg_val_loss
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1
        
        if epochs_without_improvement >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}.")
            break  

    return train_losses, val_losses, val_accuracies

# %% [markdown]
# ## Scaling up of the model
#
# If we try to run the training data on this raw model the accuracy of the validation and test data set are not as efficient as possible: they are around 60%. So, in order to improve accuracy, we try to experiment with different configurations on different levels:
#
# -   **experiment with different pooling layers**: we have four different options:
#
#     -   Max pooling;
#
#     -   Average pooling;
#
#     -   Max pooling with kernel size equals to 3 and stride size equals to 2;
#
#     -   Max pooling with kernel size equals to 3 and stride size equals to 3.

# %%
# train model with different pooling layers
models = [
    ('Max Pooling', model),
    ('Avg Pooling', model_w_avgpool),
    ('3x2 Kernel Max Pooling', model_w_3x2kmaxpool),
    ('3x3 Kernel Max Pooling', model_w_3x3kmaxpool)
]

train_losses_dict = {}
val_losses_dict = {}
val_accuracies_dict = {}

for model_name, model_instance in models:
    print(f"Training {model_name}...")
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model_instance.parameters(), lr=0.0005)
    
    train_losses, val_losses, accuracy = train_model(model_instance, train_loader, val_loader, criterion, optimizer, epochs=50)
    train_losses_dict[model_name] = train_losses
    val_losses_dict[model_name] = val_losses
    val_accuracies_dict[model_name] = accuracy
# Out:
# Training Max Pooling...
# Epoch 1, Training Loss: 0.5404, Validation Loss: 0.6006, Validation Accuracy: 70.00%
# Epoch 2, Training Loss: 0.5107, Validation Loss: 0.5828, Validation Accuracy: 71.33%
# Epoch 3, Training Loss: 0.5019, Validation Loss: 0.5562, Validation Accuracy: 73.00%
# Epoch 4, Training Loss: 0.4741, Validation Loss: 0.5441, Validation Accuracy: 74.67%
# Epoch 5, Training Loss: 0.4724, Validation Loss: 0.5497, Validation Accuracy: 74.83%
# Epoch 6, Training Loss: 0.4580, Validation Loss: 0.5618, Validation Accuracy: 73.50%
# Epoch 7, Training Loss: 0.4395, Validation Loss: 0.5464, Validation Accuracy: 73.17%
# Early stopping triggered at epoch 7.
# Training Avg Pooling...
# Epoch 1, Training Loss: 0.5892, Validation Loss: 0.6411, Validation Accuracy: 67.00%
# Epoch 2, Training Loss: 0.5627, Validation Loss: 0.5995, Validation Accuracy: 68.50%
# Epoch 3, Training Loss: 0.5473, Validation Loss: 0.6298, Validation Accuracy: 69.00%
# Epoch 4, Training Loss: 0.5416, Validation Loss: 0.6083, Validation Accuracy: 70.17%
# Epoch 5, Training Loss: 0.5198, Validation Loss: 0.6056, Validation Accuracy: 68.17%
# Early stopping triggered at epoch 5.
# Training 3x2 Kernel Max Pooling...
# Epoch 1, Training Loss: 0.5251, Validation Loss: 0.6147, Validation Accuracy: 69.17%
# Epoch 2, Training Loss: 0.4999, Validation Loss: 0.5544, Validation Accuracy: 72.33%
# Epoch 3, Training Loss: 0.4929, Validation Loss: 0.5428, Validation Accuracy: 71.67%
# Epoch 4, Training Loss: 0.4816, Validation Loss: 0.6105, Validation Accuracy: 67.50%
# Epoch 5, Training Loss: 0.4511, Validation Loss: 0.5070, Validation Accuracy: 74.83%
# Epoch 6, Training Loss: 0.4331, Validation Loss: 0.5250, Validation Accuracy: 74.67%
# Epoch 7, Training Loss: 0.4466, Validation Loss: 0.5431, Validation Accuracy: 74.00%
# Epoch 8, Training Loss: 0.4114, Validation Loss: 0.5022, Validation Accuracy: 77.33%
# Epoch 9, Training Loss: 0.3924, Validation Loss: 0.5228, Validation Accuracy: 76.17%
# Epoch 10, Training Loss: 0.3777, Validation Loss: 0.5290, Validation Accuracy: 75.17%
# Epoch 11, Training Loss: 0.3761, Validation Loss: 0.5335, Validation Accuracy: 75.67%
# Early stopping triggered at epoch 11.
# Training 3x3 Kernel Max Pooling...
# Epoch 1, Training Loss: 0.5416, Validation Loss: 0.5918, Validation Accuracy: 69.50%
# Epoch 2, Training Loss: 0.5382, Validation Loss: 0.5708, Validation Accuracy: 71.33%
# Epoch 3, Training Loss: 0.5149, Validation Loss: 0.5676, Validation Accuracy: 72.33%
# Epoch 4, Training Loss: 0.4950, Validation Loss: 0.5748, Validation Accuracy: 74.33%
# Epoch 5, Training Loss: 0.4836, Validation Loss: 0.5471, Validation Accuracy: 72.17%
# Epoch 6, Training Loss: 0.4722, Validation Loss: 0.5484, Validation Accuracy: 74.33%
# Epoch 7, Training Loss: 0.4636, Validation Loss: 0.5511, Validation Accuracy: 75.17%
# Epoch 8, Training Loss: 0.4418, Validation Loss: 0.5576, Validation Accuracy: 73.50%
# Early stopping triggered at epoch 8.

# %%
import pandas as pd

# Create a DataFrame to store results
df_results = pd.DataFrame({
    "Pooling Type": list(train_losses_dict.keys()),
    "Final Train Loss": [losses[-1] for losses in train_losses_dict.values()],
    "Final Validation Loss": [losses[-1] for losses in val_losses_dict.values()],
    "Validation Accuracy (%)": [acc for acc in val_accuracies_dict.values()]
})

# Sort by Validation Accuracy
df_results = df_results.sort_values(by="Validation Accuracy (%)", ascending=False)

# Display table
print(df_results)

# Optionally, display in a more readable format if using Jupyter Notebook
from IPython.display import display
display(df_results)

# %%
plt.figure(figsize=(18, 6))  

# Training Loss
plt.subplot(131)
for model_name in train_losses_dict:
    plt.plot(range(1, len(train_losses_dict[model_name]) + 1), train_losses_dict[model_name], label=f'{model_name} Training Loss')
plt.title("Training Loss vs. Epoch for Different Pooling Layers")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.grid(True)

# Validation Loss
plt.subplot(132)
for model_name in val_losses_dict:
    plt.plot(range(1, len(val_losses_dict[model_name]) + 1), val_losses_dict[model_name], label=f'{model_name} Validation Loss')
plt.title("Validation Loss vs. Epoch for Different Pooling Layers")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.grid(True)

# Validation Accuracy
plt.subplot(133)
for model_name in val_accuracies_dict:
    plt.plot(range(1, len(val_accuracies_dict[model_name]) + 1), val_accuracies_dict[model_name], label=f'{model_name} Validation Accuracy')
plt.title("Validation Accuracy vs. Epoch for Different Pooling Layers")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc='upper right')
plt.grid(True)

plt.tight_layout()  
plt.show()

# %% [markdown]
# The experiment gives us as the most efficient result the Max Pooling layer with kernel size equals to 3 and the stride size 2, as can be seen in the plot.
#
# - experiment with regularization techniques: we have three different options:
#     - Model with no regularization;
#     - L1 regularization;
#     - L2 regularization.

# %%
# Train models with different regularization
model_no_reg = CNN(pool_kernel=3, pool_stride=2).to(device)
model_l1 = CNN(pool_kernel=3, pool_stride=2).to(device)
model_l2 = CNN(pool_kernel=3, pool_stride=2).to(device)

optimizer_no_reg = optim.Adam(model_no_reg.parameters(), lr=0.001)
optimizer_l1 = optim.Adam(model_l1.parameters(), lr=0.001)
optimizer_l2 = optim.Adam(model_l2.parameters(), lr=0.001)

reg = [
    ('No Regularization', '', model_no_reg),
    ('L1 Regularization', 'L1', model_l1),
    ('L2 Regularization', 'L2', model_l2)
]

train_losses_dict = {}
val_losses_dict = {}
val_accuracies_dict = {}

for reg_name, reg_instance, model in reg:
    print(f"Training {reg_name}...")
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    train_losses, val_losses, accuracy = train_model(model, train_loader, val_loader, criterion, optimizer, regularization_type = reg_instance, epochs=50)
    
    train_losses_dict[reg_name] = train_losses
    val_losses_dict[reg_name] = val_losses
    val_accuracies_dict[reg_name] = accuracy
# Out:
# Training No Regularization...
# Epoch 1, Training Loss: 0.8563, Validation Loss: 0.6928, Validation Accuracy: 50.00%
# Epoch 2, Training Loss: 0.6903, Validation Loss: 0.6892, Validation Accuracy: 49.83%
# Epoch 3, Training Loss: 0.6828, Validation Loss: 0.6806, Validation Accuracy: 55.00%
# Epoch 4, Training Loss: 0.6630, Validation Loss: 0.6786, Validation Accuracy: 57.00%
# Epoch 5, Training Loss: 0.6484, Validation Loss: 0.6789, Validation Accuracy: 54.33%
# Epoch 6, Training Loss: 0.6350, Validation Loss: 0.6542, Validation Accuracy: 60.00%
# Epoch 7, Training Loss: 0.6130, Validation Loss: 0.6311, Validation Accuracy: 67.33%
# Epoch 8, Training Loss: 0.5992, Validation Loss: 0.6286, Validation Accuracy: 65.83%
# Epoch 9, Training Loss: 0.5747, Validation Loss: 0.6228, Validation Accuracy: 67.00%
# Epoch 10, Training Loss: 0.5717, Validation Loss: 0.6054, Validation Accuracy: 66.67%
# Epoch 11, Training Loss: 0.5529, Validation Loss: 0.6177, Validation Accuracy: 65.00%
# Epoch 12, Training Loss: 0.5485, Validation Loss: 0.5999, Validation Accuracy: 69.83%
# Epoch 13, Training Loss: 0.5330, Validation Loss: 0.5898, Validation Accuracy: 69.50%
# Epoch 14, Training Loss: 0.5369, Validation Loss: 0.5949, Validation Accuracy: 70.50%
# Epoch 15, Training Loss: 0.5367, Validation Loss: 0.6065, Validation Accuracy: 68.17%
# Epoch 16, Training Loss: 0.5262, Validation Loss: 0.5924, Validation Accuracy: 69.33%
# Early stopping triggered at epoch 16.
# Training L1 Regularization...
# Epoch 1, Training Loss: 0.9344, Validation Loss: 0.6948, Validation Accuracy: 50.00%
# Epoch 2, Training Loss: 0.7447, Validation Loss: 0.6924, Validation Accuracy: 52.17%
# Epoch 3, Training Loss: 0.7386, Validation Loss: 0.6902, Validation Accuracy: 51.33%
# Epoch 4, Training Loss: 0.7337, Validation Loss: 0.6874, Validation Accuracy: 54.17%
# Epoch 5, Training Loss: 0.7284, Validation Loss: 0.6884, Validation Accuracy: 54.33%
# Epoch 6, Training Loss: 0.7226, Validation Loss: 0.6841, Validation Accuracy: 60.50%
# Epoch 7, Training Loss: 0.7172, Validation Loss: 0.6805, Validation Accuracy: 61.50%
# Epoch 8, Training Loss: 0.7088, Validation Loss: 0.6767, Validation Accuracy: 58.67%
# Epoch 9, Training Loss: 0.6933, Validation Loss: 0.6738, Validation Accuracy: 59.83%
# Epoch 10, Training Loss: 0.6802, Validation Loss: 0.6576, Validation Accuracy: 62.83%
# Epoch 11, Training Loss: 0.6422, Validation Loss: 0.6204, Validation Accuracy: 64.00%
# Epoch 12, Training Loss: 0.6190, Validation Loss: 0.6277, Validation Accuracy: 65.83%
# Epoch 13, Training Loss: 0.6036, Validation Loss: 0.6296, Validation Accuracy: 66.33%
# Epoch 14, Training Loss: 0.5799, Validation Loss: 0.5997, Validation Accuracy: 68.00%
# Epoch 15, Training Loss: 0.5620, Validation Loss: 0.6096, Validation Accuracy: 66.33%
# Epoch 16, Training Loss: 0.5641, Validation Loss: 0.5779, Validation Accuracy: 69.00%
# Epoch 17, Training Loss: 0.5445, Validation Loss: 0.6278, Validation Accuracy: 68.50%
# Epoch 18, Training Loss: 0.5399, Validation Loss: 0.5845, Validation Accuracy: 69.50%
# Epoch 19, Training Loss: 0.5288, Validation Loss: 0.5732, Validation Accuracy: 68.67%
# Epoch 20, Training Loss: 0.5140, Validation Loss: 0.5453, Validation Accuracy: 73.50%
# Epoch 21, Training Loss: 0.4997, Validation Loss: 0.5673, Validation Accuracy: 69.83%
# Epoch 22, Training Loss: 0.4879, Validation Loss: 0.5394, Validation Accuracy: 73.50%
# Epoch 23, Training Loss: 0.4836, Validation Loss: 0.5306, Validation Accuracy: 73.83%
# Epoch 24, Training Loss: 0.4671, Validation Loss: 0.5527, Validation Accuracy: 73.00%
# Epoch 25, Training Loss: 0.4661, Validation Loss: 0.5243, Validation Accuracy: 73.17%
# Epoch 26, Training Loss: 0.4516, Validation Loss: 0.5110, Validation Accuracy: 74.17%
# Epoch 27, Training Loss: 0.4370, Validation Loss: 0.5109, Validation Accuracy: 74.17%
# Epoch 28, Training Loss: 0.4410, Validation Loss: 0.5057, Validation Accuracy: 75.83%
# Epoch 29, Training Loss: 0.4141, Validation Loss: 0.4883, Validation Accuracy: 77.83%
# Epoch 30, Training Loss: 0.4194, Validation Loss: 0.5423, Validation Accuracy: 71.33%
# Epoch 31, Training Loss: 0.4146, Validation Loss: 0.5349, Validation Accuracy: 76.00%
# Epoch 32, Training Loss: 0.3980, Validation Loss: 0.5047, Validation Accuracy: 76.33%
# Early stopping triggered at epoch 32.
# Training L2 Regularization...
# Epoch 1, Training Loss: 0.8288, Validation Loss: 0.6871, Validation Accuracy: 53.50%
# Epoch 2, Training Loss: 0.6879, Validation Loss: 0.6926, Validation Accuracy: 50.33%
# Epoch 3, Training Loss: 0.6892, Validation Loss: 0.6927, Validation Accuracy: 58.67%
# Epoch 4, Training Loss: 0.6599, Validation Loss: 0.6762, Validation Accuracy: 59.33%
# Epoch 5, Training Loss: 0.6669, Validation Loss: 0.6752, Validation Accuracy: 60.00%
# Epoch 6, Training Loss: 0.6346, Validation Loss: 0.6672, Validation Accuracy: 61.83%
# Epoch 7, Training Loss: 0.6411, Validation Loss: 0.6727, Validation Accuracy: 58.50%
# Epoch 8, Training Loss: 0.6189, Validation Loss: 0.6774, Validation Accuracy: 58.67%
# Epoch 9, Training Loss: 0.6088, Validation Loss: 0.6423, Validation Accuracy: 63.17%
# Epoch 10, Training Loss: 0.5954, Validation Loss: 0.6373, Validation Accuracy: 63.33%
# Epoch 11, Training Loss: 0.5734, Validation Loss: 0.6370, Validation Accuracy: 64.17%
# Epoch 12, Training Loss: 0.5605, Validation Loss: 0.6433, Validation Accuracy: 64.67%
# Epoch 13, Training Loss: 0.5492, Validation Loss: 0.6138, Validation Accuracy: 66.83%
# Epoch 14, Training Loss: 0.5434, Validation Loss: 0.6269, Validation Accuracy: 66.83%
# Epoch 15, Training Loss: 0.5365, Validation Loss: 0.6065, Validation Accuracy: 67.50%
# Epoch 16, Training Loss: 0.5153, Validation Loss: 0.6004, Validation Accuracy: 68.33%
# Epoch 17, Training Loss: 0.5097, Validation Loss: 0.6621, Validation Accuracy: 63.33%
# Epoch 18, Training Loss: 0.5019, Validation Loss: 0.5913, Validation Accuracy: 68.00%
# Epoch 19, Training Loss: 0.4861, Validation Loss: 0.5731, Validation Accuracy: 70.67%
# Epoch 20, Training Loss: 0.4772, Validation Loss: 0.6697, Validation Accuracy: 68.50%
# Epoch 21, Training Loss: 0.4602, Validation Loss: 0.6368, Validation Accuracy: 72.50%
# Epoch 22, Training Loss: 0.4644, Validation Loss: 0.5472, Validation Accuracy: 73.83%
# Epoch 23, Training Loss: 0.4512, Validation Loss: 0.5766, Validation Accuracy: 72.50%
# Epoch 24, Training Loss: 0.4328, Validation Loss: 0.5352, Validation Accuracy: 75.00%
# Epoch 25, Training Loss: 0.4290, Validation Loss: 0.5432, Validation Accuracy: 73.67%
# Epoch 26, Training Loss: 0.4150, Validation Loss: 0.5835, Validation Accuracy: 73.17%
# Epoch 27, Training Loss: 0.4110, Validation Loss: 0.5846, Validation Accuracy: 73.67%
# Early stopping triggered at epoch 27.

# %%
plt.figure(figsize=(18, 6))

# Training Loss
plt.subplot(131)
for reg_name in train_losses_dict:
    plt.plot(range(1, len(train_losses_dict[reg_name]) + 1), train_losses_dict[reg_name], label=f'{reg_name} Training Loss')
plt.title("Training Loss vs. Epoch for Different Regularization techniques")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.grid(True)

# Validation Loss
plt.subplot(132)
for reg_name in val_losses_dict:
    plt.plot(range(1, len(val_losses_dict[reg_name]) + 1), val_losses_dict[reg_name], label=f'{reg_name} Validation Loss')
plt.title("Validation Loss vs. Epoch for Different Regularization techniques")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.grid(True)

# Validation Accuracy
plt.subplot(133)
for reg_name in val_accuracies_dict:
    plt.plot(range(1, len(val_accuracies_dict[reg_name]) + 1), val_accuracies_dict[reg_name], label=f'{reg_name} Validation Accuracy')
plt.title("Validation Accuracy vs. Epoch for Different Regularization techniques")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc='upper right')
plt.grid(True)

plt.tight_layout()
plt.show()

# weight distributions
def plot_weight_distributions():
    plt.figure(figsize=(15, 5))

    plt.subplot(131)
    plt.hist(model_no_reg.fc2.weight.detach().cpu().numpy().flatten(), bins=50)
    plt.title('No Regularization')
    plt.xlabel('Weight Value')
    plt.ylabel('Count')

    plt.subplot(132)
    plt.hist(model_l1.fc2.weight.detach().cpu().numpy().flatten(), bins=50)
    plt.title('L1 Regularization')
    plt.xlabel('Weight Value')

    plt.subplot(133)
    plt.hist(model_l2.fc2.weight.detach().cpu().numpy().flatten(), bins=50)
    plt.title('L2 Regularization')
    plt.xlabel('Weight Value')

    plt.show()

plot_weight_distributions()

# %% [markdown]
# The experiment gives us as the most efficient result the L1 regularization, as can be seen in the graph.
#
# - experiment with different optimization techniques: we have five different options:
#     - Adam optimizer;
#     - AdamW optimizer: Adam with weight decay;
#     - Stochastic Gradient Descent (SGD): another parameter of a SGD could be the momentum:
#         - SGD with momentum 0.0;
#         - SGD with momentum 0.9.

# %%
# Train models with different optimizers
model_Adam = CNN(pool_kernel=3, pool_stride=2).to(device)
model_AdamW = CNN(pool_kernel=3, pool_stride=2).to(device)
model_SGD = CNN(pool_kernel=3, pool_stride=2).to(device)
model_SGD_mom00 = CNN(pool_kernel=3, pool_stride=2).to(device)
model_SGD_mom09 = CNN(pool_kernel=3, pool_stride=2).to(device)


optimizer_Adam = optim.Adam(model_Adam.parameters(), lr=0.0005) 
optimizer_AdamW = optim.AdamW(model_AdamW.parameters(), lr=0.0005) 
optimizer_SGD = optim.SGD(model_SGD.parameters(), lr=0.0005) 
optimizer_SGD_mom00 = optim.SGD(model_SGD_mom00.parameters(), lr=0.0005) 
optimizer_SGD_mom09 = optim.SGD(model_SGD_mom09.parameters(), lr=0.0005) 

opt = [
    ('Adam', optimizer_Adam, model_Adam),
    ('AdamW', optimizer_AdamW, model_AdamW),
    ('SGD', optimizer_SGD, model_SGD),
    ('SGD momentum 0.0', optimizer_SGD_mom00, model_SGD_mom00),
    ('SGD momentum 0.9', optimizer_SGD_mom09, model_SGD_mom09)
]

train_losses_dict = {}
val_losses_dict = {}
val_accuracies_dict = {}

for opt_name, optimizer_instance, model in opt:
    print(f"Training {opt_name}...")
    criterion = nn.CrossEntropyLoss()
    
    train_losses, val_losses, accuracy = train_model(model, train_loader, val_loader, criterion, optimizer_instance, regularization_type = 'L1',  epochs=50)
    
    train_losses_dict[opt_name] = train_losses
    val_losses_dict[opt_name] = val_losses
    val_accuracies_dict[opt_name] = accuracy
# Out:
# Training Adam...
# Epoch 1, Training Loss: 0.8121, Validation Loss: 0.6625, Validation Accuracy: 61.00%
# Epoch 2, Training Loss: 0.6968, Validation Loss: 0.6802, Validation Accuracy: 56.67%
# Epoch 3, Training Loss: 0.6428, Validation Loss: 0.6126, Validation Accuracy: 68.00%
# Epoch 4, Training Loss: 0.6068, Validation Loss: 0.5790, Validation Accuracy: 71.00%
# Epoch 5, Training Loss: 0.5751, Validation Loss: 0.5991, Validation Accuracy: 68.17%
# Epoch 6, Training Loss: 0.5492, Validation Loss: 0.5905, Validation Accuracy: 69.17%
# Epoch 7, Training Loss: 0.5309, Validation Loss: 0.5636, Validation Accuracy: 71.83%
# Epoch 8, Training Loss: 0.5192, Validation Loss: 0.5689, Validation Accuracy: 73.00%
# Epoch 9, Training Loss: 0.5106, Validation Loss: 0.6121, Validation Accuracy: 70.50%
# Epoch 10, Training Loss: 0.4778, Validation Loss: 0.5362, Validation Accuracy: 74.33%
# Epoch 11, Training Loss: 0.4652, Validation Loss: 0.6099, Validation Accuracy: 70.50%
# Epoch 12, Training Loss: 0.4672, Validation Loss: 0.5837, Validation Accuracy: 73.17%
# Epoch 13, Training Loss: 0.4475, Validation Loss: 0.5323, Validation Accuracy: 75.50%
# Epoch 14, Training Loss: 0.4543, Validation Loss: 0.5545, Validation Accuracy: 74.17%
# Epoch 15, Training Loss: 0.4482, Validation Loss: 0.5552, Validation Accuracy: 74.33%
# Epoch 16, Training Loss: 0.4134, Validation Loss: 0.5318, Validation Accuracy: 76.17%
# Epoch 17, Training Loss: 0.4179, Validation Loss: 0.5261, Validation Accuracy: 75.17%
# Epoch 18, Training Loss: 0.4084, Validation Loss: 0.5726, Validation Accuracy: 75.00%
# Epoch 19, Training Loss: 0.3952, Validation Loss: 0.5323, Validation Accuracy: 75.50%
# Epoch 20, Training Loss: 0.3788, Validation Loss: 0.5792, Validation Accuracy: 74.67%
# Early stopping triggered at epoch 20.
# Training AdamW...
# Epoch 1, Training Loss: 0.8410, Validation Loss: 0.6767, Validation Accuracy: 56.67%
# Epoch 2, Training Loss: 0.7241, Validation Loss: 0.6623, Validation Accuracy: 59.83%
# Epoch 3, Training Loss: 0.6537, Validation Loss: 0.6397, Validation Accuracy: 66.00%
# Epoch 4, Training Loss: 0.6172, Validation Loss: 0.6051, Validation Accuracy: 70.33%
# Epoch 5, Training Loss: 0.5953, Validation Loss: 0.5976, Validation Accuracy: 68.17%
# Epoch 6, Training Loss: 0.5613, Validation Loss: 0.5967, Validation Accuracy: 69.83%
# Epoch 7, Training Loss: 0.5755, Validation Loss: 0.5916, Validation Accuracy: 69.00%
# Epoch 8, Training Loss: 0.5438, Validation Loss: 0.5729, Validation Accuracy: 70.83%
# Epoch 9, Training Loss: 0.5314, Validation Loss: 0.5990, Validation Accuracy: 69.17%
# Epoch 10, Training Loss: 0.5073, Validation Loss: 0.5672, Validation Accuracy: 72.00%
# Epoch 11, Training Loss: 0.4827, Validation Loss: 0.5469, Validation Accuracy: 73.50%
# Epoch 12, Training Loss: 0.4650, Validation Loss: 0.5740, Validation Accuracy: 72.00%
# Epoch 13, Training Loss: 0.4709, Validation Loss: 0.5719, Validation Accuracy: 72.83%
# Epoch 14, Training Loss: 0.4575, Validation Loss: 0.5469, Validation Accuracy: 75.33%
# Epoch 15, Training Loss: 0.4392, Validation Loss: 0.5614, Validation Accuracy: 74.17%
# Epoch 16, Training Loss: 0.4370, Validation Loss: 0.5378, Validation Accuracy: 75.50%
# Epoch 17, Training Loss: 0.4231, Validation Loss: 0.5436, Validation Accuracy: 73.33%
# Epoch 18, Training Loss: 0.4075, Validation Loss: 0.5859, Validation Accuracy: 72.00%
# Epoch 19, Training Loss: 0.4015, Validation Loss: 0.5170, Validation Accuracy: 76.33%
# Epoch 20, Training Loss: 0.3963, Validation Loss: 0.5248, Validation Accuracy: 76.00%
# Epoch 21, Training Loss: 0.3937, Validation Loss: 0.5355, Validation Accuracy: 76.00%
# Epoch 22, Training Loss: 0.3793, Validation Loss: 0.5451, Validation Accuracy: 76.67%
# Early stopping triggered at epoch 22.
# Training SGD...
# Epoch 1, Training Loss: 0.8029, Validation Loss: 0.6911, Validation Accuracy: 54.83%
# Epoch 2, Training Loss: 0.8001, Validation Loss: 0.6898, Validation Accuracy: 52.83%
# Epoch 3, Training Loss: 0.7987, Validation Loss: 0.6893, Validation Accuracy: 53.17%
# Epoch 4, Training Loss: 0.7957, Validation Loss: 0.6881, Validation Accuracy: 52.67%
# Epoch 5, Training Loss: 0.7934, Validation Loss: 0.6857, Validation Accuracy: 56.67%
# Epoch 6, Training Loss: 0.7912, Validation Loss: 0.6844, Validation Accuracy: 57.83%
# Epoch 7, Training Loss: 0.7891, Validation Loss: 0.6837, Validation Accuracy: 56.83%
# Epoch 8, Training Loss: 0.7872, Validation Loss: 0.6825, Validation Accuracy: 57.17%
# Epoch 9, Training Loss: 0.7853, Validation Loss: 0.6825, Validation Accuracy: 57.83%
# Epoch 10, Training Loss: 0.7842, Validation Loss: 0.6813, Validation Accuracy: 58.50%
# Epoch 11, Training Loss: 0.7811, Validation Loss: 0.6820, Validation Accuracy: 57.00%
# Epoch 12, Training Loss: 0.7786, Validation Loss: 0.6792, Validation Accuracy: 58.17%
# Epoch 13, Training Loss: 0.7777, Validation Loss: 0.6792, Validation Accuracy: 58.33%
# Epoch 14, Training Loss: 0.7772, Validation Loss: 0.6779, Validation Accuracy: 59.17%
# Epoch 15, Training Loss: 0.7725, Validation Loss: 0.6760, Validation Accuracy: 60.00%
# Epoch 16, Training Loss: 0.7716, Validation Loss: 0.6767, Validation Accuracy: 59.00%
# Epoch 17, Training Loss: 0.7702, Validation Loss: 0.6754, Validation Accuracy: 60.00%
# Epoch 18, Training Loss: 0.7692, Validation Loss: 0.6749, Validation Accuracy: 60.33%
# Epoch 19, Training Loss: 0.7690, Validation Loss: 0.6755, Validation Accuracy: 60.00%
# Epoch 20, Training Loss: 0.7659, Validation Loss: 0.6747, Validation Accuracy: 59.67%
# Epoch 21, Training Loss: 0.7633, Validation Loss: 0.6726, Validation Accuracy: 60.17%
# Epoch 22, Training Loss: 0.7617, Validation Loss: 0.6719, Validation Accuracy: 60.00%
# Epoch 23, Training Loss: 0.7600, Validation Loss: 0.6720, Validation Accuracy: 59.83%
# Epoch 24, Training Loss: 0.7579, Validation Loss: 0.6738, Validation Accuracy: 58.17%
# Epoch 25, Training Loss: 0.7553, Validation Loss: 0.6720, Validation Accuracy: 59.83%
# Early stopping triggered at epoch 25.
# Training SGD momentum 0.0...
# Epoch 1, Training Loss: 0.8116, Validation Loss: 0.6897, Validation Accuracy: 56.83%
# Epoch 2, Training Loss: 0.8077, Validation Loss: 0.6871, Validation Accuracy: 59.00%
# Epoch 3, Training Loss: 0.8049, Validation Loss: 0.6857, Validation Accuracy: 60.50%
# Epoch 4, Training Loss: 0.8015, Validation Loss: 0.6843, Validation Accuracy: 59.67%
# Epoch 5, Training Loss: 0.7986, Validation Loss: 0.6824, Validation Accuracy: 59.00%
# Epoch 6, Training Loss: 0.7976, Validation Loss: 0.6819, Validation Accuracy: 58.50%
# Epoch 7, Training Loss: 0.7953, Validation Loss: 0.6807, Validation Accuracy: 58.83%
# Epoch 8, Training Loss: 0.7927, Validation Loss: 0.6811, Validation Accuracy: 58.17%
# Epoch 9, Training Loss: 0.7904, Validation Loss: 0.6789, Validation Accuracy: 59.33%
# Epoch 10, Training Loss: 0.7897, Validation Loss: 0.6782, Validation Accuracy: 58.67%
# Epoch 11, Training Loss: 0.7863, Validation Loss: 0.6779, Validation Accuracy: 59.33%
# Epoch 12, Training Loss: 0.7853, Validation Loss: 0.6783, Validation Accuracy: 59.33%
# Epoch 13, Training Loss: 0.7825, Validation Loss: 0.6751, Validation Accuracy: 60.17%
# Epoch 14, Training Loss: 0.7800, Validation Loss: 0.6744, Validation Accuracy: 59.00%
# Epoch 15, Training Loss: 0.7777, Validation Loss: 0.6734, Validation Accuracy: 59.33%
# Epoch 16, Training Loss: 0.7766, Validation Loss: 0.6724, Validation Accuracy: 60.17%
# Epoch 17, Training Loss: 0.7744, Validation Loss: 0.6733, Validation Accuracy: 58.00%
# Epoch 18, Training Loss: 0.7722, Validation Loss: 0.6707, Validation Accuracy: 58.83%
# Epoch 19, Training Loss: 0.7708, Validation Loss: 0.6763, Validation Accuracy: 57.00%
# Epoch 20, Training Loss: 0.7676, Validation Loss: 0.6725, Validation Accuracy: 59.67%
# Epoch 21, Training Loss: 0.7661, Validation Loss: 0.6706, Validation Accuracy: 58.50%
# Epoch 22, Training Loss: 0.7646, Validation Loss: 0.6676, Validation Accuracy: 60.83%
# Epoch 23, Training Loss: 0.7655, Validation Loss: 0.6680, Validation Accuracy: 60.83%
# Epoch 24, Training Loss: 0.7608, Validation Loss: 0.6668, Validation Accuracy: 60.67%
# Epoch 25, Training Loss: 0.7619, Validation Loss: 0.6682, Validation Accuracy: 58.67%
# Epoch 26, Training Loss: 0.7598, Validation Loss: 0.6693, Validation Accuracy: 58.83%
# Epoch 27, Training Loss: 0.7566, Validation Loss: 0.6678, Validation Accuracy: 58.67%
# Early stopping triggered at epoch 27.
# Training SGD momentum 0.9...
# Epoch 1, Training Loss: 0.8070, Validation Loss: 0.6918, Validation Accuracy: 51.17%
# Epoch 2, Training Loss: 0.8034, Validation Loss: 0.6908, Validation Accuracy: 52.33%
# Epoch 3, Training Loss: 0.8017, Validation Loss: 0.6901, Validation Accuracy: 57.00%
# Epoch 4, Training Loss: 0.7994, Validation Loss: 0.6896, Validation Accuracy: 54.00%
# Epoch 5, Training Loss: 0.7978, Validation Loss: 0.6882, Validation Accuracy: 58.17%
# Epoch 6, Training Loss: 0.7941, Validation Loss: 0.6891, Validation Accuracy: 52.33%
# Epoch 7, Training Loss: 0.7923, Validation Loss: 0.6860, Validation Accuracy: 59.17%
# Epoch 8, Training Loss: 0.7916, Validation Loss: 0.6861, Validation Accuracy: 57.50%
# Epoch 9, Training Loss: 0.7889, Validation Loss: 0.6856, Validation Accuracy: 54.83%
# Epoch 10, Training Loss: 0.7880, Validation Loss: 0.6849, Validation Accuracy: 58.33%
# Epoch 11, Training Loss: 0.7855, Validation Loss: 0.6841, Validation Accuracy: 58.33%
# Epoch 12, Training Loss: 0.7846, Validation Loss: 0.6834, Validation Accuracy: 58.00%
# Epoch 13, Training Loss: 0.7827, Validation Loss: 0.6834, Validation Accuracy: 58.50%
# Epoch 14, Training Loss: 0.7820, Validation Loss: 0.6834, Validation Accuracy: 57.83%
# Epoch 15, Training Loss: 0.7782, Validation Loss: 0.6831, Validation Accuracy: 57.83%
# Epoch 16, Training Loss: 0.7789, Validation Loss: 0.6816, Validation Accuracy: 58.00%
# Epoch 17, Training Loss: 0.7756, Validation Loss: 0.6827, Validation Accuracy: 57.17%
# Epoch 18, Training Loss: 0.7762, Validation Loss: 0.6801, Validation Accuracy: 59.00%
# Epoch 19, Training Loss: 0.7734, Validation Loss: 0.6795, Validation Accuracy: 58.33%
# Epoch 20, Training Loss: 0.7709, Validation Loss: 0.6803, Validation Accuracy: 58.17%
# Epoch 21, Training Loss: 0.7712, Validation Loss: 0.6789, Validation Accuracy: 59.17%
# Epoch 22, Training Loss: 0.7694, Validation Loss: 0.6782, Validation Accuracy: 59.83%
# Epoch 23, Training Loss: 0.7679, Validation Loss: 0.6774, Validation Accuracy: 60.50%
# Epoch 24, Training Loss: 0.7660, Validation Loss: 0.6768, Validation Accuracy: 60.67%
# Epoch 25, Training Loss: 0.7647, Validation Loss: 0.6771, Validation Accuracy: 59.50%
# Epoch 26, Training Loss: 0.7640, Validation Loss: 0.6770, Validation Accuracy: 58.33%
# Epoch 27, Training Loss: 0.7620, Validation Loss: 0.6758, Validation Accuracy: 59.83%
# Epoch 28, Training Loss: 0.7605, Validation Loss: 0.6753, Validation Accuracy: 59.50%
# Epoch 29, Training Loss: 0.7596, Validation Loss: 0.6743, Validation Accuracy: 59.83%
# Epoch 30, Training Loss: 0.7592, Validation Loss: 0.6744, Validation Accuracy: 59.00%
# Epoch 31, Training Loss: 0.7568, Validation Loss: 0.6742, Validation Accuracy: 60.33%
# Epoch 32, Training Loss: 0.7549, Validation Loss: 0.6738, Validation Accuracy: 59.83%
# Epoch 33, Training Loss: 0.7545, Validation Loss: 0.6708, Validation Accuracy: 61.17%
# Epoch 34, Training Loss: 0.7522, Validation Loss: 0.6728, Validation Accuracy: 60.67%
# Epoch 35, Training Loss: 0.7532, Validation Loss: 0.6705, Validation Accuracy: 60.50%
# Epoch 36, Training Loss: 0.7505, Validation Loss: 0.6704, Validation Accuracy: 60.83%
# Epoch 37, Training Loss: 0.7500, Validation Loss: 0.6701, Validation Accuracy: 60.67%
# Epoch 38, Training Loss: 0.7469, Validation Loss: 0.6695, Validation Accuracy: 60.33%
# Epoch 39, Training Loss: 0.7483, Validation Loss: 0.6687, Validation Accuracy: 61.50%
# Epoch 40, Training Loss: 0.7453, Validation Loss: 0.6689, Validation Accuracy: 60.83%
# Epoch 41, Training Loss: 0.7438, Validation Loss: 0.6682, Validation Accuracy: 60.83%
# Epoch 42, Training Loss: 0.7442, Validation Loss: 0.6674, Validation Accuracy: 61.17%
# Epoch 43, Training Loss: 0.7424, Validation Loss: 0.6672, Validation Accuracy: 60.33%
# Epoch 44, Training Loss: 0.7403, Validation Loss: 0.6690, Validation Accuracy: 60.50%
# Epoch 45, Training Loss: 0.7409, Validation Loss: 0.6661, Validation Accuracy: 61.00%
# Epoch 46, Training Loss: 0.7398, Validation Loss: 0.6652, Validation Accuracy: 61.00%
# Epoch 47, Training Loss: 0.7386, Validation Loss: 0.6656, Validation Accuracy: 60.67%
# Epoch 48, Training Loss: 0.7366, Validation Loss: 0.6648, Validation Accuracy: 61.83%
# Epoch 49, Training Loss: 0.7326, Validation Loss: 0.6646, Validation Accuracy: 62.00%
# Epoch 50, Training Loss: 0.7344, Validation Loss: 0.6613, Validation Accuracy: 61.50%

# %%
plt.figure(figsize=(18, 6))

# Training Loss
plt.subplot(131)
for opt_name in train_losses_dict:
    plt.plot(range(1, len(train_losses_dict[opt_name]) + 1), train_losses_dict[opt_name], label=f'{opt_name} Training Loss')
plt.title("Training Loss vs. Epoch for Different Optimisation techniques")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.grid(True)

# Validation Loss
plt.subplot(132)
for opt_name in val_losses_dict:
    plt.plot(range(1, len(val_losses_dict[opt_name]) + 1), val_losses_dict[opt_name], label=f'{opt_name} Validation Loss')
plt.title("Validation Loss vs. Epoch for Different Optimisation techniques")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.grid(True)

# Validation Accuracy
plt.subplot(133)
for opt_name in val_accuracies_dict:
    plt.plot(range(1, len(val_accuracies_dict[opt_name]) + 1), val_accuracies_dict[opt_name], label=f'{opt_name} Validation Accuracy')
plt.title("Validation Accuracy vs. Epoch for Different Optimisation techniques")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc='upper right')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# The experiment gives us as the most efficient result the Adam optimization technique, as can be seen in the plot.
#
# - experiment with different dropout rates: we have five different options:
#     - Dropout rate 0.00;
#     - Dropout rate 0.25;
#     - Dropout rate 0.50;
#     - Dropout rate 0.75;
#     - Dropout rate 1.00.

# %%
# Different dropout rates
dropout_rates = [0.0, 0.25, 0.5, 0.75, 1.0]
dropout_results = {}

for rate in dropout_rates:
    model = CNN(dropout_rate=rate, pool_kernel=3, pool_stride=2).to(device)  
    dropout_results[rate] = model

train_losses_dict = {}
val_losses_dict = {}
val_accuracies_dict = {}

for drop_name, model in dropout_results.items():
    print(f"Training with dropout rate {drop_name}...")
    
    optimizer = optim.AdamW(model.parameters(), lr=0.0005)
    
    train_losses, val_losses, val_accuracies = train_model(model, train_loader, val_loader, criterion, optimizer, regularization_type='L1', epochs=50)
    
    train_losses_dict[drop_name] = train_losses
    val_losses_dict[drop_name] = val_losses
    val_accuracies_dict[drop_name] = val_accuracies
# Out:
# Training with dropout rate 0.0...
# Epoch 1, Training Loss: 0.8455, Validation Loss: 0.6851, Validation Accuracy: 57.00%
# Epoch 2, Training Loss: 0.7230, Validation Loss: 0.6578, Validation Accuracy: 62.00%
# Epoch 3, Training Loss: 0.6723, Validation Loss: 0.6400, Validation Accuracy: 61.17%
# Epoch 4, Training Loss: 0.6433, Validation Loss: 0.6138, Validation Accuracy: 66.67%
# Epoch 5, Training Loss: 0.5977, Validation Loss: 0.6101, Validation Accuracy: 67.83%
# Epoch 6, Training Loss: 0.6020, Validation Loss: 0.5772, Validation Accuracy: 69.83%
# Epoch 7, Training Loss: 0.5643, Validation Loss: 0.6007, Validation Accuracy: 68.83%
# Epoch 8, Training Loss: 0.5446, Validation Loss: 0.5737, Validation Accuracy: 70.17%
# Epoch 9, Training Loss: 0.5185, Validation Loss: 0.5568, Validation Accuracy: 71.67%
# Epoch 10, Training Loss: 0.5052, Validation Loss: 0.5627, Validation Accuracy: 71.83%
# Epoch 11, Training Loss: 0.4888, Validation Loss: 0.5431, Validation Accuracy: 73.33%
# Epoch 12, Training Loss: 0.4628, Validation Loss: 0.6743, Validation Accuracy: 67.33%
# Epoch 13, Training Loss: 0.4652, Validation Loss: 0.5774, Validation Accuracy: 72.17%
# Epoch 14, Training Loss: 0.4501, Validation Loss: 0.5331, Validation Accuracy: 74.50%
# Epoch 15, Training Loss: 0.4464, Validation Loss: 0.5754, Validation Accuracy: 73.67%
# Epoch 16, Training Loss: 0.4449, Validation Loss: 0.5878, Validation Accuracy: 71.67%
# Epoch 17, Training Loss: 0.4291, Validation Loss: 0.5349, Validation Accuracy: 75.33%
# Early stopping triggered at epoch 17.
# Training with dropout rate 0.25...
# Epoch 1, Training Loss: 0.8204, Validation Loss: 0.6725, Validation Accuracy: 58.83%
# Epoch 2, Training Loss: 0.7130, Validation Loss: 0.6363, Validation Accuracy: 64.83%
# Epoch 3, Training Loss: 0.6619, Validation Loss: 0.5970, Validation Accuracy: 68.00%
# Epoch 4, Training Loss: 0.6257, Validation Loss: 0.6444, Validation Accuracy: 62.50%
# Epoch 5, Training Loss: 0.5928, Validation Loss: 0.5733, Validation Accuracy: 72.83%
# Epoch 6, Training Loss: 0.5777, Validation Loss: 0.5582, Validation Accuracy: 73.50%
# Epoch 7, Training Loss: 0.5673, Validation Loss: 0.5415, Validation Accuracy: 72.67%
# Epoch 8, Training Loss: 0.5381, Validation Loss: 0.5696, Validation Accuracy: 71.17%
# Epoch 9, Training Loss: 0.5210, Validation Loss: 0.5460, Validation Accuracy: 74.50%
# Epoch 10, Training Loss: 0.5188, Validation Loss: 0.5789, Validation Accuracy: 72.00%
# Early stopping triggered at epoch 10.
# Training with dropout rate 0.5...
# Epoch 1, Training Loss: 0.8512, Validation Loss: 0.6926, Validation Accuracy: 50.00%
# Epoch 2, Training Loss: 0.7589, Validation Loss: 0.6885, Validation Accuracy: 54.33%
# Epoch 3, Training Loss: 0.7343, Validation Loss: 0.6858, Validation Accuracy: 55.83%
# Epoch 4, Training Loss: 0.7178, Validation Loss: 0.6743, Validation Accuracy: 56.50%
# Epoch 5, Training Loss: 0.6973, Validation Loss: 0.6859, Validation Accuracy: 54.50%
# Epoch 6, Training Loss: 0.6773, Validation Loss: 0.6484, Validation Accuracy: 61.33%
# Epoch 7, Training Loss: 0.6500, Validation Loss: 0.6619, Validation Accuracy: 62.83%
# Epoch 8, Training Loss: 0.6273, Validation Loss: 0.6595, Validation Accuracy: 63.00%
# Epoch 9, Training Loss: 0.6193, Validation Loss: 0.6287, Validation Accuracy: 65.67%
# Epoch 10, Training Loss: 0.5985, Validation Loss: 0.6390, Validation Accuracy: 64.00%
# Epoch 11, Training Loss: 0.5831, Validation Loss: 0.6029, Validation Accuracy: 68.17%
# Epoch 12, Training Loss: 0.5727, Validation Loss: 0.5950, Validation Accuracy: 68.50%
# Epoch 13, Training Loss: 0.5487, Validation Loss: 0.6036, Validation Accuracy: 68.50%
# Epoch 14, Training Loss: 0.5443, Validation Loss: 0.5971, Validation Accuracy: 70.50%
# Epoch 15, Training Loss: 0.5416, Validation Loss: 0.5863, Validation Accuracy: 70.83%
# Epoch 16, Training Loss: 0.5291, Validation Loss: 0.6054, Validation Accuracy: 68.67%
# Epoch 17, Training Loss: 0.5226, Validation Loss: 0.6125, Validation Accuracy: 68.83%
# Epoch 18, Training Loss: 0.5001, Validation Loss: 0.5811, Validation Accuracy: 70.67%
# Epoch 19, Training Loss: 0.4921, Validation Loss: 0.5593, Validation Accuracy: 72.00%
# Epoch 20, Training Loss: 0.4862, Validation Loss: 0.5668, Validation Accuracy: 71.33%
# Epoch 21, Training Loss: 0.4856, Validation Loss: 0.5653, Validation Accuracy: 71.00%
# Epoch 22, Training Loss: 0.4738, Validation Loss: 0.5565, Validation Accuracy: 70.83%
# Epoch 23, Training Loss: 0.4697, Validation Loss: 0.5434, Validation Accuracy: 73.83%
# Epoch 24, Training Loss: 0.4675, Validation Loss: 0.5709, Validation Accuracy: 73.33%
# Epoch 25, Training Loss: 0.4624, Validation Loss: 0.5406, Validation Accuracy: 74.33%
# Epoch 26, Training Loss: 0.4478, Validation Loss: 0.5346, Validation Accuracy: 73.50%
# Epoch 27, Training Loss: 0.4248, Validation Loss: 0.5736, Validation Accuracy: 71.67%
# Epoch 28, Training Loss: 0.4300, Validation Loss: 0.5677, Validation Accuracy: 72.00%
# Epoch 29, Training Loss: 0.4270, Validation Loss: 0.5423, Validation Accuracy: 74.33%
# Early stopping triggered at epoch 29.
# Training with dropout rate 0.75...
# Epoch 1, Training Loss: 0.8389, Validation Loss: 0.6892, Validation Accuracy: 53.33%
# Epoch 2, Training Loss: 0.7419, Validation Loss: 0.6748, Validation Accuracy: 55.33%
# Epoch 3, Training Loss: 0.6944, Validation Loss: 0.6523, Validation Accuracy: 58.83%
# Epoch 4, Training Loss: 0.6564, Validation Loss: 0.6320, Validation Accuracy: 66.17%
# Epoch 5, Training Loss: 0.6179, Validation Loss: 0.6423, Validation Accuracy: 65.33%
# Epoch 6, Training Loss: 0.6136, Validation Loss: 0.5974, Validation Accuracy: 69.50%
# Epoch 7, Training Loss: 0.5698, Validation Loss: 0.5850, Validation Accuracy: 70.00%
# Epoch 8, Training Loss: 0.5658, Validation Loss: 0.5771, Validation Accuracy: 70.00%
# Epoch 9, Training Loss: 0.5755, Validation Loss: 0.5791, Validation Accuracy: 70.00%
# Epoch 10, Training Loss: 0.5497, Validation Loss: 0.5831, Validation Accuracy: 69.17%
# Epoch 11, Training Loss: 0.5378, Validation Loss: 0.5676, Validation Accuracy: 70.67%
# Epoch 12, Training Loss: 0.5264, Validation Loss: 0.5627, Validation Accuracy: 72.00%
# Epoch 13, Training Loss: 0.5232, Validation Loss: 0.5823, Validation Accuracy: 71.33%
# Epoch 14, Training Loss: 0.5196, Validation Loss: 0.5547, Validation Accuracy: 74.17%
# Epoch 15, Training Loss: 0.4973, Validation Loss: 0.5637, Validation Accuracy: 74.17%
# Epoch 16, Training Loss: 0.4973, Validation Loss: 0.5669, Validation Accuracy: 72.83%
# Epoch 17, Training Loss: 0.4727, Validation Loss: 0.5566, Validation Accuracy: 73.67%
# Early stopping triggered at epoch 17.
# Training with dropout rate 1.0...
# Epoch 1, Training Loss: 0.7701, Validation Loss: 0.6938, Validation Accuracy: 49.83%
# Epoch 2, Training Loss: 0.7187, Validation Loss: 0.6935, Validation Accuracy: 50.00%
# Epoch 3, Training Loss: 0.6964, Validation Loss: 0.6933, Validation Accuracy: 50.00%
# Epoch 4, Training Loss: 0.6935, Validation Loss: 0.6932, Validation Accuracy: 50.00%
# Epoch 5, Training Loss: 0.6934, Validation Loss: 0.6932, Validation Accuracy: 50.00%
# Epoch 6, Training Loss: 0.6934, Validation Loss: 0.6932, Validation Accuracy: 50.00%
# Epoch 7, Training Loss: 0.6934, Validation Loss: 0.6932, Validation Accuracy: 50.00%
# Epoch 8, Training Loss: 0.6934, Validation Loss: 0.6932, Validation Accuracy: 50.00%
# Epoch 9, Training Loss: 0.6934, Validation Loss: 0.6931, Validation Accuracy: 50.00%
# Epoch 10, Training Loss: 0.6934, Validation Loss: 0.6932, Validation Accuracy: 50.00%
# Epoch 11, Training Loss: 0.6934, Validation Loss: 0.6932, Validation Accuracy: 50.00%
# Epoch 12, Training Loss: 0.6933, Validation Loss: 0.6932, Validation Accuracy: 50.00%
# Early stopping triggered at epoch 12.

# %%
plt.figure(figsize=(18, 6))

# Training Loss
plt.subplot(131)
for drop_name in train_losses_dict:
    plt.plot(range(1, len(train_losses_dict[drop_name]) + 1), train_losses_dict[drop_name], label=f'{drop_name} Training Loss')
plt.title("Training Loss vs. Epoch for Different Dropout rates")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.grid(True)

# Validation Loss
plt.subplot(132)
for drop_name in val_losses_dict:
    plt.plot(range(1, len(val_losses_dict[drop_name]) + 1), val_losses_dict[drop_name], label=f'{drop_name} Validation Loss')
plt.title("Validation Loss vs. Epoch for Different Dropout rates")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.grid(True)

# Validation Accuracy
plt.subplot(133)
for drop_name in val_accuracies_dict:
    plt.plot(range(1, len(val_accuracies_dict[drop_name]) + 1), val_accuracies_dict[drop_name], label=f'{drop_name} Validation Accuracy')
plt.title("Validation Accuracy vs. Epoch for Different Dropout rates")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc='upper right')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# The experiment gives us as the most efficient result the dropout rate equals to 0.25, as can be seen in the graph.

# %%
# Step 5: Evaluate the Model
def evaluate_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    misclassified = []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            for i in range(len(labels)):
                if predicted[i] != labels[i]:
                    misclassified.append((images[i].cpu(), predicted[i].cpu(), labels[i].cpu()))

    print(f"Test Accuracy: {100 * correct / total:.2f}%")
    return misclassified if misclassified else []

misclassified_samples = evaluate_model(model, test_loader)
# Out:
# Test Accuracy: 49.50%

# %% [markdown]
# ## Final model after experiment
#
# So, for conclusion, the final model CNN has as addition:
# - a Max Pooling layer with kernel size equals to 3 and stride size equals to 2;
# - An L1 regularization;
# - AdamW optimization;
# - Dropout rate of 0.25.

# %%
# Step 6: Check Results
# a. Plot first convolutional layer filters before and after training

def plot_filters(layer, title):
    filters = layer.weight.data.cpu().numpy()
    fig, axes = plt.subplots(4, 8, figsize=(8,4))
    for i, ax in enumerate(axes.flat):
        if i < filters.shape[0]:
            ax.imshow(filters[i, 0, :, :], cmap='gray')
            ax.axis('off')
    plt.suptitle(title)
    plt.show()

plot_filters(model.conv1, "First Convolutional Layer Filters After Training")

# %%
# b. Feed an image to the first convolutional layer and plot activations
def plot_activations(model, image):
    model.eval()
    image = image.unsqueeze(0).to(device)
    with torch.no_grad():
        activation = model.conv1(image).cpu().numpy()
    fig, axes = plt.subplots(4, 8, figsize=(8,4))
    for i, ax in enumerate(axes.flat):
        if i < activation.shape[1]:
            ax.imshow(activation[0, i, :, :], cmap='gray')
            ax.axis('off')
    plt.suptitle("Activations from First Convolutional Layer")
    plt.show()

plot_activations(model, test_dataset[0][0])

# %%
# c. Plot some incorrectly classified images
def plot_misclassified(samples):
    if not samples:
        print("No misclassified samples found.")
        return
    
    fig, axes = plt.subplots(3, 3, figsize=(6,6))
    
    for i, ax in enumerate(axes.flat):
        if i < len(samples):
            img, pred, actual = samples[i]
            img = img.permute(1, 2, 0).numpy()  # Convert from (C, H, W) to (H, W, C)
            ax.imshow(img)
            ax.set_title(f"Pred: {pred}, Actual: {actual}")
            ax.axis('off')
    
    plt.suptitle("Misclassified Samples")
    plt.show()

plot_misclassified(misclassified_samples)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9372549..0.5764706].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.99215686..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.78039217..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.92156863..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..0.9843137].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.99215686..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].

# %% [markdown]
# ## Issue with eperiment
#
# However, the choice of all these configurations are based on a sequential experiment meaning that changing the order of the configuration, the result will probably change. So, for a better experiment, we decide to perform all the possible combination of the configuration of the model: this I shingly expensive from a time point of view since it will be 120 combinations. The results are highly difficult to visualize: we tried with a parallel lines plot even if it is not a suitable configuration.

# %%
# Configurations for pooling layers, regularization, optimizers, dropout rates, momentum
pooling_options = ['max', 'avg']
regularization_options = ['L1', 'L2', 'None']
optimizer_options = ['Adam', 'AdamW', 'SGD']
dropout_rates = [0.0, 0.25, 0.5, 0.75]
momentum_values = [0.0, 0.9]

results = {}  # Store results for different configurations

for pooling in pooling_options:
    for reg in regularization_options:
        for opt in optimizer_options:
            for dropout in dropout_rates:
                for momentum in momentum_values:
                    model = CNN(pool_type=pooling, dropout_rate=dropout).to(device)
                    criterion = nn.CrossEntropyLoss()
                    
                    if opt == 'SGD':
                        optimizer = optim.SGD(model.parameters(), lr=0.0005, momentum=momentum)  # SGD with momentum
                    elif opt == 'Adam':
                        optimizer = optim.Adam(model.parameters(), lr=0.0005)  # Adam optimizer, no momentum
                    elif opt == 'AdamW':
                        optimizer = optim.AdamW(model.parameters(), lr=0.0005)  # AdamW optimizer, no momentum

                    # Train the model with the current configuration
                    print(f"Training with {pooling} pooling, {reg} regularization, {opt} optimizer, {dropout} dropout, {momentum} momentum...")
                    train_losses, val_losses, val_accuracies = train_model(model, train_loader, val_loader, criterion, optimizer, epochs=50)

                    # Store the results
                    results[(pooling, reg, opt, dropout, momentum)] = {
                        'train_losses': train_losses,
                        'val_losses': val_losses,
                        'val_accuracies': val_accuracies
                    }
# Out:
# Training with max pooling, L1 regularization, Adam optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7472, Validation Loss: 0.6708, Validation Accuracy: 58.00%
# Epoch 2, Training Loss: 0.6256, Validation Loss: 0.6345, Validation Accuracy: 67.67%
# Epoch 3, Training Loss: 0.5553, Validation Loss: 0.6578, Validation Accuracy: 63.67%
# Epoch 4, Training Loss: 0.4650, Validation Loss: 0.5994, Validation Accuracy: 69.17%
# Epoch 5, Training Loss: 0.3500, Validation Loss: 0.6486, Validation Accuracy: 68.00%
# Training with max pooling, L1 regularization, Adam optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7458, Validation Loss: 0.6653, Validation Accuracy: 60.50%
# Epoch 2, Training Loss: 0.6354, Validation Loss: 0.6185, Validation Accuracy: 66.67%
# Epoch 3, Training Loss: 0.5479, Validation Loss: 0.6234, Validation Accuracy: 67.33%
# Epoch 4, Training Loss: 0.4146, Validation Loss: 0.6380, Validation Accuracy: 65.67%
# Epoch 5, Training Loss: 0.2938, Validation Loss: 0.7215, Validation Accuracy: 68.50%
# Early stopping triggered at epoch 5.
# Training with max pooling, L1 regularization, Adam optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.6897, Validation Loss: 0.6656, Validation Accuracy: 60.50%
# Epoch 2, Training Loss: 0.5663, Validation Loss: 0.6118, Validation Accuracy: 68.33%
# Epoch 3, Training Loss: 0.4605, Validation Loss: 0.6235, Validation Accuracy: 67.33%
# Epoch 4, Training Loss: 0.3329, Validation Loss: 0.7577, Validation Accuracy: 63.67%
# Epoch 5, Training Loss: 0.2224, Validation Loss: 0.6984, Validation Accuracy: 70.17%
# Early stopping triggered at epoch 5.
# Training with max pooling, L1 regularization, Adam optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7459, Validation Loss: 0.6792, Validation Accuracy: 58.50%
# Epoch 2, Training Loss: 0.6556, Validation Loss: 0.6508, Validation Accuracy: 61.83%
# Epoch 3, Training Loss: 0.5894, Validation Loss: 0.6172, Validation Accuracy: 68.67%
# Epoch 4, Training Loss: 0.5092, Validation Loss: 0.6283, Validation Accuracy: 65.83%
# Epoch 5, Training Loss: 0.4080, Validation Loss: 0.6338, Validation Accuracy: 66.33%
# Training with max pooling, L1 regularization, Adam optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7446, Validation Loss: 0.6734, Validation Accuracy: 56.33%
# Epoch 2, Training Loss: 0.6330, Validation Loss: 0.6416, Validation Accuracy: 64.83%
# Epoch 3, Training Loss: 0.5480, Validation Loss: 0.6603, Validation Accuracy: 64.83%
# Epoch 4, Training Loss: 0.4617, Validation Loss: 0.6205, Validation Accuracy: 68.83%
# Epoch 5, Training Loss: 0.3702, Validation Loss: 0.6832, Validation Accuracy: 68.67%
# Training with max pooling, L1 regularization, Adam optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7230, Validation Loss: 0.6672, Validation Accuracy: 62.33%
# Epoch 2, Training Loss: 0.6266, Validation Loss: 0.6269, Validation Accuracy: 66.33%
# Epoch 3, Training Loss: 0.5510, Validation Loss: 0.6088, Validation Accuracy: 69.17%
# Epoch 4, Training Loss: 0.4752, Validation Loss: 0.5960, Validation Accuracy: 71.33%
# Epoch 5, Training Loss: 0.3851, Validation Loss: 0.6270, Validation Accuracy: 66.33%
# Training with max pooling, L1 regularization, Adam optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7594, Validation Loss: 0.6808, Validation Accuracy: 54.50%
# Epoch 2, Training Loss: 0.6695, Validation Loss: 0.6841, Validation Accuracy: 55.17%
# Epoch 3, Training Loss: 0.6532, Validation Loss: 0.6845, Validation Accuracy: 58.67%
# Epoch 4, Training Loss: 0.6308, Validation Loss: 0.6619, Validation Accuracy: 61.33%
# Epoch 5, Training Loss: 0.5901, Validation Loss: 0.6401, Validation Accuracy: 66.33%
# Training with max pooling, L1 regularization, Adam optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7184, Validation Loss: 0.6791, Validation Accuracy: 61.17%
# Epoch 2, Training Loss: 0.6574, Validation Loss: 0.6569, Validation Accuracy: 64.00%
# Epoch 3, Training Loss: 0.6145, Validation Loss: 0.6456, Validation Accuracy: 64.00%
# Epoch 4, Training Loss: 0.5770, Validation Loss: 0.6221, Validation Accuracy: 64.17%
# Epoch 5, Training Loss: 0.5167, Validation Loss: 0.6357, Validation Accuracy: 66.50%
# Training with max pooling, L1 regularization, AdamW optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7937, Validation Loss: 0.6922, Validation Accuracy: 51.83%
# Epoch 2, Training Loss: 0.6937, Validation Loss: 0.6827, Validation Accuracy: 56.83%
# Epoch 3, Training Loss: 0.6578, Validation Loss: 0.7055, Validation Accuracy: 57.00%
# Epoch 4, Training Loss: 0.6057, Validation Loss: 0.6498, Validation Accuracy: 59.00%
# Epoch 5, Training Loss: 0.5227, Validation Loss: 0.6076, Validation Accuracy: 70.00%
# Training with max pooling, L1 regularization, AdamW optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7488, Validation Loss: 0.6852, Validation Accuracy: 54.50%
# Epoch 2, Training Loss: 0.6138, Validation Loss: 0.6200, Validation Accuracy: 68.33%
# Epoch 3, Training Loss: 0.5280, Validation Loss: 0.6197, Validation Accuracy: 65.83%
# Epoch 4, Training Loss: 0.4288, Validation Loss: 0.6202, Validation Accuracy: 69.33%
# Epoch 5, Training Loss: 0.2953, Validation Loss: 0.7078, Validation Accuracy: 68.33%
# Training with max pooling, L1 regularization, AdamW optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7719, Validation Loss: 0.6811, Validation Accuracy: 56.50%
# Epoch 2, Training Loss: 0.6451, Validation Loss: 0.6572, Validation Accuracy: 61.17%
# Epoch 3, Training Loss: 0.5726, Validation Loss: 0.6110, Validation Accuracy: 67.67%
# Epoch 4, Training Loss: 0.5044, Validation Loss: 0.7030, Validation Accuracy: 62.00%
# Epoch 5, Training Loss: 0.4014, Validation Loss: 0.6834, Validation Accuracy: 65.33%
# Training with max pooling, L1 regularization, AdamW optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7610, Validation Loss: 0.6844, Validation Accuracy: 55.83%
# Epoch 2, Training Loss: 0.6660, Validation Loss: 0.6560, Validation Accuracy: 63.83%
# Epoch 3, Training Loss: 0.5971, Validation Loss: 0.6286, Validation Accuracy: 66.00%
# Epoch 4, Training Loss: 0.5070, Validation Loss: 0.6114, Validation Accuracy: 69.00%
# Epoch 5, Training Loss: 0.3907, Validation Loss: 0.6229, Validation Accuracy: 68.00%
# Training with max pooling, L1 regularization, AdamW optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7266, Validation Loss: 0.6801, Validation Accuracy: 55.17%
# Epoch 2, Training Loss: 0.6576, Validation Loss: 0.6464, Validation Accuracy: 64.17%
# Epoch 3, Training Loss: 0.5813, Validation Loss: 0.6371, Validation Accuracy: 64.67%
# Epoch 4, Training Loss: 0.5120, Validation Loss: 0.5851, Validation Accuracy: 69.67%
# Epoch 5, Training Loss: 0.4266, Validation Loss: 0.5825, Validation Accuracy: 71.00%
# Training with max pooling, L1 regularization, AdamW optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7358, Validation Loss: 0.6819, Validation Accuracy: 54.33%
# Epoch 2, Training Loss: 0.6568, Validation Loss: 0.6508, Validation Accuracy: 63.17%
# Epoch 3, Training Loss: 0.6021, Validation Loss: 0.6309, Validation Accuracy: 64.17%
# Epoch 4, Training Loss: 0.5337, Validation Loss: 0.6190, Validation Accuracy: 66.83%
# Epoch 5, Training Loss: 0.4562, Validation Loss: 0.6198, Validation Accuracy: 66.67%
# Training with max pooling, L1 regularization, AdamW optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7647, Validation Loss: 0.6846, Validation Accuracy: 54.00%
# Epoch 2, Training Loss: 0.6658, Validation Loss: 0.6829, Validation Accuracy: 57.67%
# Epoch 3, Training Loss: 0.6443, Validation Loss: 0.6762, Validation Accuracy: 59.50%
# Epoch 4, Training Loss: 0.6097, Validation Loss: 0.6545, Validation Accuracy: 61.33%
# Epoch 5, Training Loss: 0.5859, Validation Loss: 0.6240, Validation Accuracy: 67.17%
# Training with max pooling, L1 regularization, AdamW optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7513, Validation Loss: 0.6866, Validation Accuracy: 54.67%
# Epoch 2, Training Loss: 0.6830, Validation Loss: 0.6693, Validation Accuracy: 60.00%
# Epoch 3, Training Loss: 0.6287, Validation Loss: 0.6552, Validation Accuracy: 64.17%
# Epoch 4, Training Loss: 0.5841, Validation Loss: 0.6360, Validation Accuracy: 67.17%
# Epoch 5, Training Loss: 0.5453, Validation Loss: 0.6224, Validation Accuracy: 66.33%
# Training with max pooling, L1 regularization, SGD optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7016, Validation Loss: 0.6921, Validation Accuracy: 50.00%
# Epoch 2, Training Loss: 0.6991, Validation Loss: 0.6909, Validation Accuracy: 52.17%
# Epoch 3, Training Loss: 0.6974, Validation Loss: 0.6897, Validation Accuracy: 54.67%
# Epoch 4, Training Loss: 0.6958, Validation Loss: 0.6888, Validation Accuracy: 56.33%
# Epoch 5, Training Loss: 0.6939, Validation Loss: 0.6880, Validation Accuracy: 56.67%
# Training with max pooling, L1 regularization, SGD optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7002, Validation Loss: 0.6889, Validation Accuracy: 57.50%
# Epoch 2, Training Loss: 0.6928, Validation Loss: 0.6876, Validation Accuracy: 51.83%
# Epoch 3, Training Loss: 0.6883, Validation Loss: 0.6798, Validation Accuracy: 59.50%
# Epoch 4, Training Loss: 0.6782, Validation Loss: 0.6751, Validation Accuracy: 60.83%
# Epoch 5, Training Loss: 0.6695, Validation Loss: 0.6699, Validation Accuracy: 62.33%
# Training with max pooling, L1 regularization, SGD optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7016, Validation Loss: 0.6922, Validation Accuracy: 53.50%
# Epoch 2, Training Loss: 0.6987, Validation Loss: 0.6911, Validation Accuracy: 54.50%
# Epoch 3, Training Loss: 0.6970, Validation Loss: 0.6905, Validation Accuracy: 52.00%
# Epoch 4, Training Loss: 0.6959, Validation Loss: 0.6897, Validation Accuracy: 52.50%
# Epoch 5, Training Loss: 0.6938, Validation Loss: 0.6883, Validation Accuracy: 56.17%
# Training with max pooling, L1 regularization, SGD optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6985, Validation Loss: 0.6876, Validation Accuracy: 55.17%
# Epoch 2, Training Loss: 0.6922, Validation Loss: 0.6853, Validation Accuracy: 56.17%
# Epoch 3, Training Loss: 0.6801, Validation Loss: 0.6755, Validation Accuracy: 60.00%
# Epoch 4, Training Loss: 0.6710, Validation Loss: 0.6718, Validation Accuracy: 60.00%
# Epoch 5, Training Loss: 0.6612, Validation Loss: 0.6672, Validation Accuracy: 60.00%
# Training with max pooling, L1 regularization, SGD optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7004, Validation Loss: 0.6919, Validation Accuracy: 56.00%
# Epoch 2, Training Loss: 0.6999, Validation Loss: 0.6915, Validation Accuracy: 51.83%
# Epoch 3, Training Loss: 0.6988, Validation Loss: 0.6898, Validation Accuracy: 57.33%
# Epoch 4, Training Loss: 0.6961, Validation Loss: 0.6887, Validation Accuracy: 57.83%
# Epoch 5, Training Loss: 0.6953, Validation Loss: 0.6881, Validation Accuracy: 58.00%
# Training with max pooling, L1 regularization, SGD optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6997, Validation Loss: 0.6898, Validation Accuracy: 50.67%
# Epoch 2, Training Loss: 0.6956, Validation Loss: 0.6831, Validation Accuracy: 57.00%
# Epoch 3, Training Loss: 0.6869, Validation Loss: 0.6811, Validation Accuracy: 55.67%
# Epoch 4, Training Loss: 0.6764, Validation Loss: 0.6710, Validation Accuracy: 59.50%
# Epoch 5, Training Loss: 0.6728, Validation Loss: 0.6739, Validation Accuracy: 57.00%
# Training with max pooling, L1 regularization, SGD optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7020, Validation Loss: 0.6927, Validation Accuracy: 50.50%
# Epoch 2, Training Loss: 0.7004, Validation Loss: 0.6918, Validation Accuracy: 49.83%
# Epoch 3, Training Loss: 0.7007, Validation Loss: 0.6908, Validation Accuracy: 55.17%
# Epoch 4, Training Loss: 0.6981, Validation Loss: 0.6901, Validation Accuracy: 54.67%
# Epoch 5, Training Loss: 0.6996, Validation Loss: 0.6895, Validation Accuracy: 57.50%
# Training with max pooling, L1 regularization, SGD optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7039, Validation Loss: 0.6910, Validation Accuracy: 52.67%
# Epoch 2, Training Loss: 0.6999, Validation Loss: 0.6900, Validation Accuracy: 51.50%
# Epoch 3, Training Loss: 0.6973, Validation Loss: 0.6886, Validation Accuracy: 54.00%
# Epoch 4, Training Loss: 0.6962, Validation Loss: 0.6878, Validation Accuracy: 54.50%
# Epoch 5, Training Loss: 0.6945, Validation Loss: 0.6861, Validation Accuracy: 56.33%
# Training with max pooling, L2 regularization, Adam optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7282, Validation Loss: 0.6608, Validation Accuracy: 59.50%
# Epoch 2, Training Loss: 0.6135, Validation Loss: 0.6330, Validation Accuracy: 66.50%
# Epoch 3, Training Loss: 0.5234, Validation Loss: 0.6490, Validation Accuracy: 66.17%
# Epoch 4, Training Loss: 0.3990, Validation Loss: 0.6161, Validation Accuracy: 69.67%
# Epoch 5, Training Loss: 0.2622, Validation Loss: 0.7364, Validation Accuracy: 65.67%
# Training with max pooling, L2 regularization, Adam optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7379, Validation Loss: 0.6655, Validation Accuracy: 59.50%
# Epoch 2, Training Loss: 0.6295, Validation Loss: 0.6783, Validation Accuracy: 56.00%
# Epoch 3, Training Loss: 0.5541, Validation Loss: 0.6283, Validation Accuracy: 66.33%
# Epoch 4, Training Loss: 0.4925, Validation Loss: 0.6320, Validation Accuracy: 65.50%
# Epoch 5, Training Loss: 0.3712, Validation Loss: 0.6974, Validation Accuracy: 64.00%
# Training with max pooling, L2 regularization, Adam optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.6919, Validation Loss: 0.6406, Validation Accuracy: 63.67%
# Epoch 2, Training Loss: 0.5802, Validation Loss: 0.6366, Validation Accuracy: 64.33%
# Epoch 3, Training Loss: 0.4624, Validation Loss: 0.6135, Validation Accuracy: 68.17%
# Epoch 4, Training Loss: 0.3541, Validation Loss: 0.6079, Validation Accuracy: 70.67%
# Epoch 5, Training Loss: 0.2269, Validation Loss: 0.6779, Validation Accuracy: 68.50%
# Training with max pooling, L2 regularization, Adam optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7434, Validation Loss: 0.6830, Validation Accuracy: 55.50%
# Epoch 2, Training Loss: 0.6431, Validation Loss: 0.6383, Validation Accuracy: 64.17%
# Epoch 3, Training Loss: 0.5568, Validation Loss: 0.6289, Validation Accuracy: 66.17%
# Epoch 4, Training Loss: 0.4543, Validation Loss: 0.6235, Validation Accuracy: 68.17%
# Epoch 5, Training Loss: 0.3504, Validation Loss: 0.6375, Validation Accuracy: 69.67%
# Training with max pooling, L2 regularization, Adam optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7455, Validation Loss: 0.6768, Validation Accuracy: 57.67%
# Epoch 2, Training Loss: 0.6190, Validation Loss: 0.6454, Validation Accuracy: 62.83%
# Epoch 3, Training Loss: 0.5522, Validation Loss: 0.6196, Validation Accuracy: 67.67%
# Epoch 4, Training Loss: 0.4802, Validation Loss: 0.6917, Validation Accuracy: 63.33%
# Epoch 5, Training Loss: 0.4062, Validation Loss: 0.6423, Validation Accuracy: 69.17%
# Training with max pooling, L2 regularization, Adam optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7314, Validation Loss: 0.6813, Validation Accuracy: 56.67%
# Epoch 2, Training Loss: 0.6673, Validation Loss: 0.6815, Validation Accuracy: 58.50%
# Epoch 3, Training Loss: 0.6090, Validation Loss: 0.6313, Validation Accuracy: 65.67%
# Epoch 4, Training Loss: 0.5342, Validation Loss: 0.6084, Validation Accuracy: 67.33%
# Epoch 5, Training Loss: 0.4426, Validation Loss: 0.6157, Validation Accuracy: 68.17%
# Training with max pooling, L2 regularization, Adam optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7218, Validation Loss: 0.6740, Validation Accuracy: 59.50%
# Epoch 2, Training Loss: 0.6577, Validation Loss: 0.6539, Validation Accuracy: 65.50%
# Epoch 3, Training Loss: 0.6282, Validation Loss: 0.6431, Validation Accuracy: 64.00%
# Epoch 4, Training Loss: 0.5810, Validation Loss: 0.6337, Validation Accuracy: 64.17%
# Epoch 5, Training Loss: 0.5340, Validation Loss: 0.6294, Validation Accuracy: 67.33%
# Training with max pooling, L2 regularization, Adam optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7392, Validation Loss: 0.6769, Validation Accuracy: 56.50%
# Epoch 2, Training Loss: 0.6676, Validation Loss: 0.6695, Validation Accuracy: 56.33%
# Epoch 3, Training Loss: 0.6464, Validation Loss: 0.6442, Validation Accuracy: 66.33%
# Epoch 4, Training Loss: 0.6007, Validation Loss: 0.6259, Validation Accuracy: 67.67%
# Epoch 5, Training Loss: 0.5581, Validation Loss: 0.5960, Validation Accuracy: 70.00%
# Training with max pooling, L2 regularization, AdamW optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7257, Validation Loss: 0.6748, Validation Accuracy: 58.17%
# Epoch 2, Training Loss: 0.6216, Validation Loss: 0.8518, Validation Accuracy: 54.83%
# Epoch 3, Training Loss: 0.5248, Validation Loss: 0.6356, Validation Accuracy: 66.33%
# Epoch 4, Training Loss: 0.4058, Validation Loss: 0.6487, Validation Accuracy: 67.67%
# Epoch 5, Training Loss: 0.2931, Validation Loss: 0.7272, Validation Accuracy: 67.17%
# Training with max pooling, L2 regularization, AdamW optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7576, Validation Loss: 0.6769, Validation Accuracy: 56.83%
# Epoch 2, Training Loss: 0.6329, Validation Loss: 0.6417, Validation Accuracy: 63.33%
# Epoch 3, Training Loss: 0.5400, Validation Loss: 0.6011, Validation Accuracy: 67.83%
# Epoch 4, Training Loss: 0.4396, Validation Loss: 0.6265, Validation Accuracy: 69.17%
# Epoch 5, Training Loss: 0.3108, Validation Loss: 0.6363, Validation Accuracy: 70.00%
# Training with max pooling, L2 regularization, AdamW optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7139, Validation Loss: 0.6817, Validation Accuracy: 58.33%
# Epoch 2, Training Loss: 0.5972, Validation Loss: 0.6360, Validation Accuracy: 68.33%
# Epoch 3, Training Loss: 0.5244, Validation Loss: 0.6230, Validation Accuracy: 68.33%
# Epoch 4, Training Loss: 0.4188, Validation Loss: 0.6382, Validation Accuracy: 67.67%
# Epoch 5, Training Loss: 0.3080, Validation Loss: 0.6369, Validation Accuracy: 67.50%
# Training with max pooling, L2 regularization, AdamW optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7792, Validation Loss: 0.6754, Validation Accuracy: 58.17%
# Epoch 2, Training Loss: 0.6341, Validation Loss: 0.6445, Validation Accuracy: 60.00%
# Epoch 3, Training Loss: 0.5547, Validation Loss: 0.6782, Validation Accuracy: 63.33%
# Epoch 4, Training Loss: 0.4479, Validation Loss: 0.6314, Validation Accuracy: 66.33%
# Epoch 5, Training Loss: 0.3323, Validation Loss: 0.6460, Validation Accuracy: 66.00%
# Training with max pooling, L2 regularization, AdamW optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7248, Validation Loss: 0.6630, Validation Accuracy: 58.33%
# Epoch 2, Training Loss: 0.6392, Validation Loss: 0.6345, Validation Accuracy: 66.83%
# Epoch 3, Training Loss: 0.5832, Validation Loss: 0.6140, Validation Accuracy: 67.00%
# Epoch 4, Training Loss: 0.5047, Validation Loss: 0.5858, Validation Accuracy: 70.17%
# Epoch 5, Training Loss: 0.4160, Validation Loss: 0.6062, Validation Accuracy: 68.50%
# Training with max pooling, L2 regularization, AdamW optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7401, Validation Loss: 0.6691, Validation Accuracy: 58.33%
# Epoch 2, Training Loss: 0.6451, Validation Loss: 0.6597, Validation Accuracy: 62.17%
# Epoch 3, Training Loss: 0.5821, Validation Loss: 0.6324, Validation Accuracy: 65.33%
# Epoch 4, Training Loss: 0.4927, Validation Loss: 0.6112, Validation Accuracy: 67.33%
# Epoch 5, Training Loss: 0.3896, Validation Loss: 0.6614, Validation Accuracy: 66.50%
# Training with max pooling, L2 regularization, AdamW optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7429, Validation Loss: 0.6860, Validation Accuracy: 52.50%
# Epoch 2, Training Loss: 0.6772, Validation Loss: 0.6709, Validation Accuracy: 60.33%
# Epoch 3, Training Loss: 0.6302, Validation Loss: 0.6487, Validation Accuracy: 62.83%
# Epoch 4, Training Loss: 0.5689, Validation Loss: 0.6166, Validation Accuracy: 68.83%
# Epoch 5, Training Loss: 0.5012, Validation Loss: 0.5943, Validation Accuracy: 69.17%
# Training with max pooling, L2 regularization, AdamW optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7690, Validation Loss: 0.6790, Validation Accuracy: 56.83%
# Epoch 2, Training Loss: 0.6554, Validation Loss: 0.6584, Validation Accuracy: 65.17%
# Epoch 3, Training Loss: 0.6263, Validation Loss: 0.6388, Validation Accuracy: 68.00%
# Epoch 4, Training Loss: 0.5784, Validation Loss: 0.6272, Validation Accuracy: 66.83%
# Epoch 5, Training Loss: 0.5177, Validation Loss: 0.6026, Validation Accuracy: 69.17%
# Training with max pooling, L2 regularization, SGD optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7003, Validation Loss: 0.6922, Validation Accuracy: 52.67%
# Epoch 2, Training Loss: 0.6982, Validation Loss: 0.6911, Validation Accuracy: 57.00%
# Epoch 3, Training Loss: 0.6968, Validation Loss: 0.6902, Validation Accuracy: 56.67%
# Epoch 4, Training Loss: 0.6951, Validation Loss: 0.6901, Validation Accuracy: 52.50%
# Epoch 5, Training Loss: 0.6939, Validation Loss: 0.6885, Validation Accuracy: 56.00%
# Training with max pooling, L2 regularization, SGD optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6986, Validation Loss: 0.6908, Validation Accuracy: 50.50%
# Epoch 2, Training Loss: 0.6891, Validation Loss: 0.6824, Validation Accuracy: 56.00%
# Epoch 3, Training Loss: 0.6794, Validation Loss: 0.6748, Validation Accuracy: 60.17%
# Epoch 4, Training Loss: 0.6697, Validation Loss: 0.6843, Validation Accuracy: 56.00%
# Epoch 5, Training Loss: 0.6619, Validation Loss: 0.6630, Validation Accuracy: 61.83%
# Training with max pooling, L2 regularization, SGD optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7015, Validation Loss: 0.6922, Validation Accuracy: 51.50%
# Epoch 2, Training Loss: 0.7000, Validation Loss: 0.6913, Validation Accuracy: 54.33%
# Epoch 3, Training Loss: 0.6982, Validation Loss: 0.6907, Validation Accuracy: 54.83%
# Epoch 4, Training Loss: 0.6975, Validation Loss: 0.6901, Validation Accuracy: 55.67%
# Epoch 5, Training Loss: 0.6959, Validation Loss: 0.6894, Validation Accuracy: 56.00%
# Training with max pooling, L2 regularization, SGD optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6993, Validation Loss: 0.6905, Validation Accuracy: 50.33%
# Epoch 2, Training Loss: 0.6951, Validation Loss: 0.6808, Validation Accuracy: 60.50%
# Epoch 3, Training Loss: 0.6857, Validation Loss: 0.6772, Validation Accuracy: 59.67%
# Epoch 4, Training Loss: 0.6735, Validation Loss: 0.6690, Validation Accuracy: 62.00%
# Epoch 5, Training Loss: 0.6646, Validation Loss: 0.6671, Validation Accuracy: 60.50%
# Training with max pooling, L2 regularization, SGD optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7008, Validation Loss: 0.6915, Validation Accuracy: 54.33%
# Epoch 2, Training Loss: 0.6989, Validation Loss: 0.6904, Validation Accuracy: 56.00%
# Epoch 3, Training Loss: 0.6976, Validation Loss: 0.6896, Validation Accuracy: 56.83%
# Epoch 4, Training Loss: 0.6965, Validation Loss: 0.6889, Validation Accuracy: 57.83%
# Epoch 5, Training Loss: 0.6941, Validation Loss: 0.6877, Validation Accuracy: 55.00%
# Training with max pooling, L2 regularization, SGD optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7000, Validation Loss: 0.6885, Validation Accuracy: 52.83%
# Epoch 2, Training Loss: 0.6948, Validation Loss: 0.6842, Validation Accuracy: 56.50%
# Epoch 3, Training Loss: 0.6861, Validation Loss: 0.6821, Validation Accuracy: 55.33%
# Epoch 4, Training Loss: 0.6796, Validation Loss: 0.6776, Validation Accuracy: 56.33%
# Epoch 5, Training Loss: 0.6740, Validation Loss: 0.6713, Validation Accuracy: 59.17%
# Training with max pooling, L2 regularization, SGD optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7020, Validation Loss: 0.6925, Validation Accuracy: 50.17%
# Epoch 2, Training Loss: 0.7003, Validation Loss: 0.6909, Validation Accuracy: 57.67%
# Epoch 3, Training Loss: 0.6979, Validation Loss: 0.6900, Validation Accuracy: 59.00%
# Epoch 4, Training Loss: 0.6973, Validation Loss: 0.6897, Validation Accuracy: 56.83%
# Epoch 5, Training Loss: 0.6969, Validation Loss: 0.6887, Validation Accuracy: 57.83%
# Training with max pooling, L2 regularization, SGD optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7021, Validation Loss: 0.6910, Validation Accuracy: 51.17%
# Epoch 2, Training Loss: 0.6981, Validation Loss: 0.6888, Validation Accuracy: 54.50%
# Epoch 3, Training Loss: 0.6912, Validation Loss: 0.6858, Validation Accuracy: 54.83%
# Epoch 4, Training Loss: 0.6861, Validation Loss: 0.6815, Validation Accuracy: 56.50%
# Epoch 5, Training Loss: 0.6864, Validation Loss: 0.6795, Validation Accuracy: 56.83%
# Training with max pooling, None regularization, Adam optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7663, Validation Loss: 0.6856, Validation Accuracy: 50.83%
# Epoch 2, Training Loss: 0.6532, Validation Loss: 0.6599, Validation Accuracy: 59.17%
# Epoch 3, Training Loss: 0.5601, Validation Loss: 0.5986, Validation Accuracy: 68.50%
# Epoch 4, Training Loss: 0.4023, Validation Loss: 0.6170, Validation Accuracy: 67.83%
# Epoch 5, Training Loss: 0.2580, Validation Loss: 0.7350, Validation Accuracy: 68.17%
# Training with max pooling, None regularization, Adam optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7439, Validation Loss: 0.6867, Validation Accuracy: 50.00%
# Epoch 2, Training Loss: 0.6713, Validation Loss: 0.6702, Validation Accuracy: 60.67%
# Epoch 3, Training Loss: 0.6131, Validation Loss: 0.6302, Validation Accuracy: 65.00%
# Epoch 4, Training Loss: 0.5073, Validation Loss: 0.6380, Validation Accuracy: 65.67%
# Epoch 5, Training Loss: 0.3951, Validation Loss: 0.6200, Validation Accuracy: 68.33%
# Training with max pooling, None regularization, Adam optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7133, Validation Loss: 0.6750, Validation Accuracy: 59.67%
# Epoch 2, Training Loss: 0.6538, Validation Loss: 0.6554, Validation Accuracy: 62.67%
# Epoch 3, Training Loss: 0.5679, Validation Loss: 0.6898, Validation Accuracy: 65.33%
# Epoch 4, Training Loss: 0.4912, Validation Loss: 0.6099, Validation Accuracy: 70.00%
# Epoch 5, Training Loss: 0.3825, Validation Loss: 0.6380, Validation Accuracy: 69.50%
# Training with max pooling, None regularization, Adam optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6785, Validation Loss: 0.6782, Validation Accuracy: 58.67%
# Epoch 2, Training Loss: 0.5706, Validation Loss: 0.6098, Validation Accuracy: 68.00%
# Epoch 3, Training Loss: 0.4711, Validation Loss: 0.6593, Validation Accuracy: 66.00%
# Epoch 4, Training Loss: 0.3543, Validation Loss: 0.7044, Validation Accuracy: 68.17%
# Epoch 5, Training Loss: 0.2366, Validation Loss: 0.7509, Validation Accuracy: 66.17%
# Early stopping triggered at epoch 5.
# Training with max pooling, None regularization, Adam optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7253, Validation Loss: 0.6705, Validation Accuracy: 57.33%
# Epoch 2, Training Loss: 0.6333, Validation Loss: 0.6364, Validation Accuracy: 65.50%
# Epoch 3, Training Loss: 0.5596, Validation Loss: 0.6357, Validation Accuracy: 66.17%
# Epoch 4, Training Loss: 0.4773, Validation Loss: 0.6358, Validation Accuracy: 68.83%
# Epoch 5, Training Loss: 0.4063, Validation Loss: 0.6328, Validation Accuracy: 69.50%
# Training with max pooling, None regularization, Adam optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7224, Validation Loss: 0.6747, Validation Accuracy: 58.33%
# Epoch 2, Training Loss: 0.6290, Validation Loss: 0.6410, Validation Accuracy: 64.50%
# Epoch 3, Training Loss: 0.5458, Validation Loss: 0.6414, Validation Accuracy: 63.83%
# Epoch 4, Training Loss: 0.4544, Validation Loss: 0.6306, Validation Accuracy: 67.83%
# Epoch 5, Training Loss: 0.3489, Validation Loss: 0.6947, Validation Accuracy: 68.00%
# Training with max pooling, None regularization, Adam optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7774, Validation Loss: 0.6855, Validation Accuracy: 50.33%
# Epoch 2, Training Loss: 0.6764, Validation Loss: 0.6696, Validation Accuracy: 57.00%
# Epoch 3, Training Loss: 0.6454, Validation Loss: 0.6691, Validation Accuracy: 59.17%
# Epoch 4, Training Loss: 0.5961, Validation Loss: 0.6333, Validation Accuracy: 65.50%
# Epoch 5, Training Loss: 0.5261, Validation Loss: 0.6654, Validation Accuracy: 63.50%
# Training with max pooling, None regularization, Adam optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7299, Validation Loss: 0.6815, Validation Accuracy: 52.00%
# Epoch 2, Training Loss: 0.6653, Validation Loss: 0.6784, Validation Accuracy: 58.17%
# Epoch 3, Training Loss: 0.6524, Validation Loss: 0.6587, Validation Accuracy: 63.50%
# Epoch 4, Training Loss: 0.6098, Validation Loss: 0.6552, Validation Accuracy: 64.33%
# Epoch 5, Training Loss: 0.5772, Validation Loss: 0.6435, Validation Accuracy: 64.67%
# Training with max pooling, None regularization, AdamW optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7225, Validation Loss: 0.6559, Validation Accuracy: 62.50%
# Epoch 2, Training Loss: 0.5967, Validation Loss: 0.6246, Validation Accuracy: 65.83%
# Epoch 3, Training Loss: 0.5211, Validation Loss: 0.6150, Validation Accuracy: 68.83%
# Epoch 4, Training Loss: 0.4360, Validation Loss: 0.6034, Validation Accuracy: 68.33%
# Epoch 5, Training Loss: 0.3306, Validation Loss: 0.6699, Validation Accuracy: 68.83%
# Training with max pooling, None regularization, AdamW optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7498, Validation Loss: 0.6811, Validation Accuracy: 56.83%
# Epoch 2, Training Loss: 0.6607, Validation Loss: 0.6523, Validation Accuracy: 61.67%
# Epoch 3, Training Loss: 0.5967, Validation Loss: 0.6226, Validation Accuracy: 63.83%
# Epoch 4, Training Loss: 0.4969, Validation Loss: 0.6316, Validation Accuracy: 66.67%
# Epoch 5, Training Loss: 0.3895, Validation Loss: 0.6041, Validation Accuracy: 68.50%
# Training with max pooling, None regularization, AdamW optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7178, Validation Loss: 0.6679, Validation Accuracy: 59.50%
# Epoch 2, Training Loss: 0.6202, Validation Loss: 0.6370, Validation Accuracy: 67.00%
# Epoch 3, Training Loss: 0.5483, Validation Loss: 0.6364, Validation Accuracy: 67.83%
# Epoch 4, Training Loss: 0.4361, Validation Loss: 0.7164, Validation Accuracy: 66.17%
# Epoch 5, Training Loss: 0.3369, Validation Loss: 0.6200, Validation Accuracy: 68.33%
# Training with max pooling, None regularization, AdamW optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7484, Validation Loss: 0.6742, Validation Accuracy: 57.67%
# Epoch 2, Training Loss: 0.6393, Validation Loss: 0.6284, Validation Accuracy: 66.67%
# Epoch 3, Training Loss: 0.5733, Validation Loss: 0.6187, Validation Accuracy: 67.50%
# Epoch 4, Training Loss: 0.5000, Validation Loss: 0.6327, Validation Accuracy: 66.00%
# Epoch 5, Training Loss: 0.4026, Validation Loss: 0.5955, Validation Accuracy: 70.00%
# Training with max pooling, None regularization, AdamW optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7413, Validation Loss: 0.6863, Validation Accuracy: 55.17%
# Epoch 2, Training Loss: 0.6620, Validation Loss: 0.6598, Validation Accuracy: 61.67%
# Epoch 3, Training Loss: 0.6067, Validation Loss: 0.6302, Validation Accuracy: 64.67%
# Epoch 4, Training Loss: 0.5316, Validation Loss: 0.6050, Validation Accuracy: 69.67%
# Epoch 5, Training Loss: 0.4184, Validation Loss: 0.6000, Validation Accuracy: 69.50%
# Training with max pooling, None regularization, AdamW optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7120, Validation Loss: 0.6653, Validation Accuracy: 60.33%
# Epoch 2, Training Loss: 0.6275, Validation Loss: 0.6256, Validation Accuracy: 66.67%
# Epoch 3, Training Loss: 0.5333, Validation Loss: 0.6041, Validation Accuracy: 69.50%
# Epoch 4, Training Loss: 0.4154, Validation Loss: 0.6057, Validation Accuracy: 71.00%
# Epoch 5, Training Loss: 0.3083, Validation Loss: 0.6812, Validation Accuracy: 68.33%
# Training with max pooling, None regularization, AdamW optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7129, Validation Loss: 0.6809, Validation Accuracy: 53.83%
# Epoch 2, Training Loss: 0.6609, Validation Loss: 0.6709, Validation Accuracy: 56.50%
# Epoch 3, Training Loss: 0.6151, Validation Loss: 0.6752, Validation Accuracy: 61.00%
# Epoch 4, Training Loss: 0.5501, Validation Loss: 0.6171, Validation Accuracy: 68.67%
# Epoch 5, Training Loss: 0.4836, Validation Loss: 0.6312, Validation Accuracy: 66.33%
# Training with max pooling, None regularization, AdamW optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7155, Validation Loss: 0.6850, Validation Accuracy: 55.83%
# Epoch 2, Training Loss: 0.6555, Validation Loss: 0.7203, Validation Accuracy: 53.83%
# Epoch 3, Training Loss: 0.6065, Validation Loss: 0.6435, Validation Accuracy: 65.17%
# Epoch 4, Training Loss: 0.5561, Validation Loss: 0.6383, Validation Accuracy: 68.33%
# Epoch 5, Training Loss: 0.4848, Validation Loss: 0.6106, Validation Accuracy: 68.33%
# Training with max pooling, None regularization, SGD optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7015, Validation Loss: 0.6929, Validation Accuracy: 50.67%
# Epoch 2, Training Loss: 0.6998, Validation Loss: 0.6919, Validation Accuracy: 51.50%
# Epoch 3, Training Loss: 0.6985, Validation Loss: 0.6909, Validation Accuracy: 53.83%
# Epoch 4, Training Loss: 0.6972, Validation Loss: 0.6901, Validation Accuracy: 56.67%
# Epoch 5, Training Loss: 0.6960, Validation Loss: 0.6892, Validation Accuracy: 56.50%
# Training with max pooling, None regularization, SGD optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6982, Validation Loss: 0.6836, Validation Accuracy: 57.33%
# Epoch 2, Training Loss: 0.6817, Validation Loss: 0.6739, Validation Accuracy: 60.17%
# Epoch 3, Training Loss: 0.6677, Validation Loss: 0.6676, Validation Accuracy: 60.00%
# Epoch 4, Training Loss: 0.6530, Validation Loss: 0.6646, Validation Accuracy: 57.67%
# Epoch 5, Training Loss: 0.6404, Validation Loss: 0.6574, Validation Accuracy: 63.33%
# Training with max pooling, None regularization, SGD optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7023, Validation Loss: 0.6921, Validation Accuracy: 50.50%
# Epoch 2, Training Loss: 0.7000, Validation Loss: 0.6910, Validation Accuracy: 55.67%
# Epoch 3, Training Loss: 0.6985, Validation Loss: 0.6900, Validation Accuracy: 57.83%
# Epoch 4, Training Loss: 0.6969, Validation Loss: 0.6886, Validation Accuracy: 60.67%
# Epoch 5, Training Loss: 0.6956, Validation Loss: 0.6876, Validation Accuracy: 59.17%
# Training with max pooling, None regularization, SGD optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7019, Validation Loss: 0.6898, Validation Accuracy: 51.00%
# Epoch 2, Training Loss: 0.6920, Validation Loss: 0.6846, Validation Accuracy: 55.33%
# Epoch 3, Training Loss: 0.6875, Validation Loss: 0.6804, Validation Accuracy: 58.50%
# Epoch 4, Training Loss: 0.6781, Validation Loss: 0.6752, Validation Accuracy: 61.33%
# Epoch 5, Training Loss: 0.6685, Validation Loss: 0.6699, Validation Accuracy: 59.83%
# Training with max pooling, None regularization, SGD optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7012, Validation Loss: 0.6919, Validation Accuracy: 53.83%
# Epoch 2, Training Loss: 0.6986, Validation Loss: 0.6908, Validation Accuracy: 55.67%
# Epoch 3, Training Loss: 0.6979, Validation Loss: 0.6898, Validation Accuracy: 57.17%
# Epoch 4, Training Loss: 0.6959, Validation Loss: 0.6888, Validation Accuracy: 56.17%
# Epoch 5, Training Loss: 0.6945, Validation Loss: 0.6880, Validation Accuracy: 58.17%
# Training with max pooling, None regularization, SGD optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7007, Validation Loss: 0.6882, Validation Accuracy: 56.83%
# Epoch 2, Training Loss: 0.6945, Validation Loss: 0.6843, Validation Accuracy: 58.67%
# Epoch 3, Training Loss: 0.6891, Validation Loss: 0.6806, Validation Accuracy: 58.00%
# Epoch 4, Training Loss: 0.6785, Validation Loss: 0.6801, Validation Accuracy: 55.67%
# Epoch 5, Training Loss: 0.6738, Validation Loss: 0.6735, Validation Accuracy: 60.67%
# Training with max pooling, None regularization, SGD optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7024, Validation Loss: 0.6923, Validation Accuracy: 50.17%
# Epoch 2, Training Loss: 0.7007, Validation Loss: 0.6914, Validation Accuracy: 52.33%
# Epoch 3, Training Loss: 0.6986, Validation Loss: 0.6904, Validation Accuracy: 56.83%
# Epoch 4, Training Loss: 0.6973, Validation Loss: 0.6894, Validation Accuracy: 55.83%
# Epoch 5, Training Loss: 0.6957, Validation Loss: 0.6883, Validation Accuracy: 58.00%
# Training with max pooling, None regularization, SGD optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7019, Validation Loss: 0.6912, Validation Accuracy: 56.50%
# Epoch 2, Training Loss: 0.6969, Validation Loss: 0.6892, Validation Accuracy: 58.17%
# Epoch 3, Training Loss: 0.6940, Validation Loss: 0.6865, Validation Accuracy: 59.50%
# Epoch 4, Training Loss: 0.6943, Validation Loss: 0.6849, Validation Accuracy: 59.17%
# Epoch 5, Training Loss: 0.6911, Validation Loss: 0.6830, Validation Accuracy: 58.00%
# Training with avg pooling, L1 regularization, Adam optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7896, Validation Loss: 0.6813, Validation Accuracy: 59.33%
# Epoch 2, Training Loss: 0.6600, Validation Loss: 0.6635, Validation Accuracy: 60.67%
# Epoch 3, Training Loss: 0.6034, Validation Loss: 0.6468, Validation Accuracy: 64.67%
# Epoch 4, Training Loss: 0.5260, Validation Loss: 0.6322, Validation Accuracy: 64.67%
# Epoch 5, Training Loss: 0.4298, Validation Loss: 0.6488, Validation Accuracy: 67.00%
# Training with avg pooling, L1 regularization, Adam optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7000, Validation Loss: 0.6500, Validation Accuracy: 61.67%
# Epoch 2, Training Loss: 0.6156, Validation Loss: 0.6292, Validation Accuracy: 65.50%
# Epoch 3, Training Loss: 0.5378, Validation Loss: 0.6320, Validation Accuracy: 65.33%
# Epoch 4, Training Loss: 0.4587, Validation Loss: 0.6206, Validation Accuracy: 68.50%
# Epoch 5, Training Loss: 0.3615, Validation Loss: 0.7343, Validation Accuracy: 64.00%
# Training with avg pooling, L1 regularization, Adam optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7010, Validation Loss: 0.6841, Validation Accuracy: 58.67%
# Epoch 2, Training Loss: 0.6188, Validation Loss: 0.6378, Validation Accuracy: 65.83%
# Epoch 3, Training Loss: 0.5600, Validation Loss: 0.6191, Validation Accuracy: 68.33%
# Epoch 4, Training Loss: 0.4788, Validation Loss: 0.6061, Validation Accuracy: 69.17%
# Epoch 5, Training Loss: 0.3814, Validation Loss: 0.6431, Validation Accuracy: 68.17%
# Training with avg pooling, L1 regularization, Adam optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7397, Validation Loss: 0.6869, Validation Accuracy: 54.67%
# Epoch 2, Training Loss: 0.6701, Validation Loss: 0.6736, Validation Accuracy: 58.00%
# Epoch 3, Training Loss: 0.6015, Validation Loss: 0.7057, Validation Accuracy: 58.50%
# Epoch 4, Training Loss: 0.5422, Validation Loss: 0.6312, Validation Accuracy: 65.33%
# Epoch 5, Training Loss: 0.4547, Validation Loss: 0.6290, Validation Accuracy: 67.67%
# Training with avg pooling, L1 regularization, Adam optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7044, Validation Loss: 0.6960, Validation Accuracy: 58.00%
# Epoch 2, Training Loss: 0.6631, Validation Loss: 0.6752, Validation Accuracy: 61.17%
# Epoch 3, Training Loss: 0.5979, Validation Loss: 0.6281, Validation Accuracy: 65.33%
# Epoch 4, Training Loss: 0.5316, Validation Loss: 0.6777, Validation Accuracy: 66.83%
# Epoch 5, Training Loss: 0.4430, Validation Loss: 0.6239, Validation Accuracy: 69.00%
# Training with avg pooling, L1 regularization, Adam optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7079, Validation Loss: 0.6706, Validation Accuracy: 60.83%
# Epoch 2, Training Loss: 0.6445, Validation Loss: 0.6563, Validation Accuracy: 62.50%
# Epoch 3, Training Loss: 0.5953, Validation Loss: 0.6434, Validation Accuracy: 63.83%
# Epoch 4, Training Loss: 0.5391, Validation Loss: 0.6243, Validation Accuracy: 66.50%
# Epoch 5, Training Loss: 0.4480, Validation Loss: 0.6120, Validation Accuracy: 68.33%
# Training with avg pooling, L1 regularization, Adam optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7292, Validation Loss: 0.6837, Validation Accuracy: 55.67%
# Epoch 2, Training Loss: 0.6611, Validation Loss: 0.6856, Validation Accuracy: 60.33%
# Epoch 3, Training Loss: 0.6274, Validation Loss: 0.6899, Validation Accuracy: 62.17%
# Epoch 4, Training Loss: 0.6059, Validation Loss: 0.6549, Validation Accuracy: 65.67%
# Epoch 5, Training Loss: 0.5693, Validation Loss: 0.6398, Validation Accuracy: 66.33%
# Training with avg pooling, L1 regularization, Adam optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7520, Validation Loss: 0.6865, Validation Accuracy: 53.83%
# Epoch 2, Training Loss: 0.6892, Validation Loss: 0.6726, Validation Accuracy: 59.50%
# Epoch 3, Training Loss: 0.6674, Validation Loss: 0.6626, Validation Accuracy: 62.50%
# Epoch 4, Training Loss: 0.6161, Validation Loss: 0.6654, Validation Accuracy: 61.17%
# Epoch 5, Training Loss: 0.5819, Validation Loss: 0.6799, Validation Accuracy: 64.33%
# Training with avg pooling, L1 regularization, AdamW optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7180, Validation Loss: 0.6839, Validation Accuracy: 54.33%
# Epoch 2, Training Loss: 0.6333, Validation Loss: 0.6498, Validation Accuracy: 61.50%
# Epoch 3, Training Loss: 0.5811, Validation Loss: 0.6675, Validation Accuracy: 64.67%
# Epoch 4, Training Loss: 0.5308, Validation Loss: 0.6611, Validation Accuracy: 64.17%
# Epoch 5, Training Loss: 0.4596, Validation Loss: 0.6911, Validation Accuracy: 63.00%
# Early stopping triggered at epoch 5.
# Training with avg pooling, L1 regularization, AdamW optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7119, Validation Loss: 0.6703, Validation Accuracy: 60.17%
# Epoch 2, Training Loss: 0.6133, Validation Loss: 0.6750, Validation Accuracy: 64.17%
# Epoch 3, Training Loss: 0.5589, Validation Loss: 0.7005, Validation Accuracy: 63.67%
# Epoch 4, Training Loss: 0.4900, Validation Loss: 0.6361, Validation Accuracy: 65.50%
# Epoch 5, Training Loss: 0.4152, Validation Loss: 0.6816, Validation Accuracy: 64.83%
# Training with avg pooling, L1 regularization, AdamW optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7003, Validation Loss: 0.6644, Validation Accuracy: 60.17%
# Epoch 2, Training Loss: 0.6139, Validation Loss: 0.6437, Validation Accuracy: 64.17%
# Epoch 3, Training Loss: 0.5225, Validation Loss: 0.6747, Validation Accuracy: 63.00%
# Epoch 4, Training Loss: 0.4358, Validation Loss: 0.6304, Validation Accuracy: 67.67%
# Epoch 5, Training Loss: 0.3236, Validation Loss: 0.6495, Validation Accuracy: 68.17%
# Training with avg pooling, L1 regularization, AdamW optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6710, Validation Loss: 0.6596, Validation Accuracy: 61.33%
# Epoch 2, Training Loss: 0.5993, Validation Loss: 0.6323, Validation Accuracy: 66.33%
# Epoch 3, Training Loss: 0.5420, Validation Loss: 0.6598, Validation Accuracy: 64.50%
# Epoch 4, Training Loss: 0.4600, Validation Loss: 0.6522, Validation Accuracy: 67.17%
# Epoch 5, Training Loss: 0.3618, Validation Loss: 0.7133, Validation Accuracy: 66.50%
# Early stopping triggered at epoch 5.
# Training with avg pooling, L1 regularization, AdamW optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7168, Validation Loss: 0.6654, Validation Accuracy: 60.67%
# Epoch 2, Training Loss: 0.6313, Validation Loss: 0.6456, Validation Accuracy: 63.50%
# Epoch 3, Training Loss: 0.5814, Validation Loss: 0.6492, Validation Accuracy: 65.17%
# Epoch 4, Training Loss: 0.5140, Validation Loss: 0.6467, Validation Accuracy: 61.67%
# Epoch 5, Training Loss: 0.4260, Validation Loss: 0.6346, Validation Accuracy: 68.00%
# Training with avg pooling, L1 regularization, AdamW optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7342, Validation Loss: 0.6829, Validation Accuracy: 51.17%
# Epoch 2, Training Loss: 0.6579, Validation Loss: 0.6535, Validation Accuracy: 63.83%
# Epoch 3, Training Loss: 0.6064, Validation Loss: 0.6380, Validation Accuracy: 67.50%
# Epoch 4, Training Loss: 0.5699, Validation Loss: 0.6327, Validation Accuracy: 68.17%
# Epoch 5, Training Loss: 0.5106, Validation Loss: 0.6403, Validation Accuracy: 63.17%
# Training with avg pooling, L1 regularization, AdamW optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7265, Validation Loss: 0.6779, Validation Accuracy: 59.67%
# Epoch 2, Training Loss: 0.6637, Validation Loss: 0.6636, Validation Accuracy: 59.33%
# Epoch 3, Training Loss: 0.6285, Validation Loss: 0.6638, Validation Accuracy: 62.50%
# Epoch 4, Training Loss: 0.5751, Validation Loss: 0.6446, Validation Accuracy: 65.00%
# Epoch 5, Training Loss: 0.5239, Validation Loss: 0.6152, Validation Accuracy: 67.00%
# Training with avg pooling, L1 regularization, AdamW optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7199, Validation Loss: 0.6834, Validation Accuracy: 55.17%
# Epoch 2, Training Loss: 0.6678, Validation Loss: 0.6810, Validation Accuracy: 58.33%
# Epoch 3, Training Loss: 0.6409, Validation Loss: 0.6753, Validation Accuracy: 60.17%
# Epoch 4, Training Loss: 0.6140, Validation Loss: 0.6637, Validation Accuracy: 62.17%
# Epoch 5, Training Loss: 0.5973, Validation Loss: 0.6447, Validation Accuracy: 66.00%
# Training with avg pooling, L1 regularization, SGD optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7026, Validation Loss: 0.6915, Validation Accuracy: 54.67%
# Epoch 2, Training Loss: 0.6997, Validation Loss: 0.6903, Validation Accuracy: 53.33%
# Epoch 3, Training Loss: 0.6985, Validation Loss: 0.6894, Validation Accuracy: 56.17%
# Epoch 4, Training Loss: 0.6975, Validation Loss: 0.6888, Validation Accuracy: 53.83%
# Epoch 5, Training Loss: 0.6965, Validation Loss: 0.6880, Validation Accuracy: 56.83%
# Training with avg pooling, L1 regularization, SGD optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7008, Validation Loss: 0.6892, Validation Accuracy: 57.67%
# Epoch 2, Training Loss: 0.6943, Validation Loss: 0.6853, Validation Accuracy: 54.00%
# Epoch 3, Training Loss: 0.6873, Validation Loss: 0.6797, Validation Accuracy: 56.67%
# Epoch 4, Training Loss: 0.6809, Validation Loss: 0.6778, Validation Accuracy: 59.17%
# Epoch 5, Training Loss: 0.6727, Validation Loss: 0.6710, Validation Accuracy: 60.33%
# Training with avg pooling, L1 regularization, SGD optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7010, Validation Loss: 0.6922, Validation Accuracy: 52.33%
# Epoch 2, Training Loss: 0.6989, Validation Loss: 0.6911, Validation Accuracy: 53.83%
# Epoch 3, Training Loss: 0.6970, Validation Loss: 0.6899, Validation Accuracy: 54.33%
# Epoch 4, Training Loss: 0.6945, Validation Loss: 0.6888, Validation Accuracy: 55.00%
# Epoch 5, Training Loss: 0.6930, Validation Loss: 0.6878, Validation Accuracy: 56.17%
# Training with avg pooling, L1 regularization, SGD optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6975, Validation Loss: 0.6872, Validation Accuracy: 56.17%
# Epoch 2, Training Loss: 0.6881, Validation Loss: 0.6819, Validation Accuracy: 57.50%
# Epoch 3, Training Loss: 0.6806, Validation Loss: 0.6781, Validation Accuracy: 57.50%
# Epoch 4, Training Loss: 0.6731, Validation Loss: 0.6738, Validation Accuracy: 60.00%
# Epoch 5, Training Loss: 0.6639, Validation Loss: 0.6709, Validation Accuracy: 60.50%
# Training with avg pooling, L1 regularization, SGD optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7028, Validation Loss: 0.6934, Validation Accuracy: 50.17%
# ...
# Epoch 1, Training Loss: 0.7006, Validation Loss: 0.6911, Validation Accuracy: 51.83%
# Epoch 2, Training Loss: 0.6949, Validation Loss: 0.6861, Validation Accuracy: 59.00%
# Epoch 3, Training Loss: 0.6886, Validation Loss: 0.6829, Validation Accuracy: 56.50%
# Epoch 4, Training Loss: 0.6833, Validation Loss: 0.6787, Validation Accuracy: 58.33%
# Epoch 5, Training Loss: 0.6768, Validation Loss: 0.6753, Validation Accuracy: 58.50%
# Training with avg pooling, L2 regularization, SGD optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7026, Validation Loss: 0.6911, Validation Accuracy: 53.83%
# Epoch 2, Training Loss: 0.6995, Validation Loss: 0.6900, Validation Accuracy: 57.50%
# Epoch 3, Training Loss: 0.6981, Validation Loss: 0.6893, Validation Accuracy: 56.33%
# Epoch 4, Training Loss: 0.6969, Validation Loss: 0.6884, Validation Accuracy: 57.67%
# Epoch 5, Training Loss: 0.6958, Validation Loss: 0.6877, Validation Accuracy: 59.17%
# Training with avg pooling, L2 regularization, SGD optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7024, Validation Loss: 0.6900, Validation Accuracy: 52.67%
# Epoch 2, Training Loss: 0.6952, Validation Loss: 0.6871, Validation Accuracy: 54.67%
# Epoch 3, Training Loss: 0.6896, Validation Loss: 0.6859, Validation Accuracy: 53.33%
# Epoch 4, Training Loss: 0.6860, Validation Loss: 0.6785, Validation Accuracy: 56.33%
# Epoch 5, Training Loss: 0.6767, Validation Loss: 0.6985, Validation Accuracy: 51.50%
# Training with avg pooling, L2 regularization, SGD optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7018, Validation Loss: 0.6926, Validation Accuracy: 50.00%
# Epoch 2, Training Loss: 0.7001, Validation Loss: 0.6918, Validation Accuracy: 52.33%
# Epoch 3, Training Loss: 0.6996, Validation Loss: 0.6912, Validation Accuracy: 53.83%
# Epoch 4, Training Loss: 0.6977, Validation Loss: 0.6906, Validation Accuracy: 54.50%
# Epoch 5, Training Loss: 0.6969, Validation Loss: 0.6901, Validation Accuracy: 56.17%
# Training with avg pooling, L2 regularization, SGD optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7006, Validation Loss: 0.6881, Validation Accuracy: 52.50%
# Epoch 2, Training Loss: 0.6933, Validation Loss: 0.6830, Validation Accuracy: 57.67%
# Epoch 3, Training Loss: 0.6845, Validation Loss: 0.6807, Validation Accuracy: 57.83%
# Epoch 4, Training Loss: 0.6796, Validation Loss: 0.6755, Validation Accuracy: 60.00%
# Epoch 5, Training Loss: 0.6695, Validation Loss: 0.6708, Validation Accuracy: 60.33%
# Training with avg pooling, L2 regularization, SGD optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7038, Validation Loss: 0.6936, Validation Accuracy: 50.00%
# Epoch 2, Training Loss: 0.7016, Validation Loss: 0.6927, Validation Accuracy: 50.50%
# Epoch 3, Training Loss: 0.6998, Validation Loss: 0.6916, Validation Accuracy: 49.67%
# Epoch 4, Training Loss: 0.6994, Validation Loss: 0.6910, Validation Accuracy: 49.50%
# Epoch 5, Training Loss: 0.6961, Validation Loss: 0.6902, Validation Accuracy: 50.00%
# Training with avg pooling, L2 regularization, SGD optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7002, Validation Loss: 0.6897, Validation Accuracy: 52.33%
# Epoch 2, Training Loss: 0.6952, Validation Loss: 0.6872, Validation Accuracy: 54.00%
# Epoch 3, Training Loss: 0.6925, Validation Loss: 0.6844, Validation Accuracy: 55.67%
# Epoch 4, Training Loss: 0.6892, Validation Loss: 0.6830, Validation Accuracy: 55.83%
# Epoch 5, Training Loss: 0.6836, Validation Loss: 0.6780, Validation Accuracy: 58.50%
# Training with avg pooling, None regularization, Adam optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7397, Validation Loss: 0.6703, Validation Accuracy: 57.83%
# Epoch 2, Training Loss: 0.6229, Validation Loss: 0.6258, Validation Accuracy: 64.67%
# Epoch 3, Training Loss: 0.5479, Validation Loss: 0.6202, Validation Accuracy: 66.50%
# Epoch 4, Training Loss: 0.4497, Validation Loss: 0.6206, Validation Accuracy: 66.67%
# Epoch 5, Training Loss: 0.3377, Validation Loss: 0.7457, Validation Accuracy: 64.67%
# Training with avg pooling, None regularization, Adam optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7200, Validation Loss: 0.6821, Validation Accuracy: 56.33%
# Epoch 2, Training Loss: 0.6437, Validation Loss: 0.6516, Validation Accuracy: 62.33%
# Epoch 3, Training Loss: 0.5896, Validation Loss: 0.6633, Validation Accuracy: 63.33%
# Epoch 4, Training Loss: 0.5022, Validation Loss: 0.6356, Validation Accuracy: 66.50%
# Epoch 5, Training Loss: 0.4123, Validation Loss: 0.6648, Validation Accuracy: 66.33%
# Training with avg pooling, None regularization, Adam optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.6980, Validation Loss: 0.6672, Validation Accuracy: 58.67%
# Epoch 2, Training Loss: 0.6273, Validation Loss: 0.6492, Validation Accuracy: 62.00%
# Epoch 3, Training Loss: 0.5576, Validation Loss: 0.6450, Validation Accuracy: 66.00%
# Epoch 4, Training Loss: 0.4684, Validation Loss: 0.6334, Validation Accuracy: 67.67%
# Epoch 5, Training Loss: 0.3687, Validation Loss: 0.6801, Validation Accuracy: 68.00%
# Training with avg pooling, None regularization, Adam optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7056, Validation Loss: 0.6652, Validation Accuracy: 60.67%
# Epoch 2, Training Loss: 0.6251, Validation Loss: 0.6433, Validation Accuracy: 65.83%
# Epoch 3, Training Loss: 0.5637, Validation Loss: 0.6235, Validation Accuracy: 65.83%
# Epoch 4, Training Loss: 0.4706, Validation Loss: 0.6544, Validation Accuracy: 68.00%
# Epoch 5, Training Loss: 0.3886, Validation Loss: 0.6527, Validation Accuracy: 67.50%
# Training with avg pooling, None regularization, Adam optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.6998, Validation Loss: 0.6643, Validation Accuracy: 60.50%
# Epoch 2, Training Loss: 0.6371, Validation Loss: 0.6365, Validation Accuracy: 62.83%
# Epoch 3, Training Loss: 0.5692, Validation Loss: 0.6248, Validation Accuracy: 66.00%
# Epoch 4, Training Loss: 0.4949, Validation Loss: 0.6485, Validation Accuracy: 64.83%
# Epoch 5, Training Loss: 0.4071, Validation Loss: 0.6806, Validation Accuracy: 65.67%
# Training with avg pooling, None regularization, Adam optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7466, Validation Loss: 0.6784, Validation Accuracy: 56.67%
# Epoch 2, Training Loss: 0.6466, Validation Loss: 0.6451, Validation Accuracy: 62.33%
# Epoch 3, Training Loss: 0.6017, Validation Loss: 0.6459, Validation Accuracy: 62.83%
# Epoch 4, Training Loss: 0.5369, Validation Loss: 0.6622, Validation Accuracy: 64.17%
# Epoch 5, Training Loss: 0.4691, Validation Loss: 0.6441, Validation Accuracy: 67.50%
# Training with avg pooling, None regularization, Adam optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7163, Validation Loss: 0.6817, Validation Accuracy: 55.83%
# Epoch 2, Training Loss: 0.6647, Validation Loss: 0.6950, Validation Accuracy: 55.00%
# Epoch 3, Training Loss: 0.6387, Validation Loss: 0.6490, Validation Accuracy: 65.17%
# Epoch 4, Training Loss: 0.6034, Validation Loss: 0.6406, Validation Accuracy: 64.33%
# Epoch 5, Training Loss: 0.5537, Validation Loss: 0.6288, Validation Accuracy: 64.83%
# Training with avg pooling, None regularization, Adam optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7116, Validation Loss: 0.6825, Validation Accuracy: 56.67%
# Epoch 2, Training Loss: 0.6688, Validation Loss: 0.6622, Validation Accuracy: 60.17%
# Epoch 3, Training Loss: 0.6467, Validation Loss: 0.6573, Validation Accuracy: 63.50%
# Epoch 4, Training Loss: 0.6067, Validation Loss: 0.6601, Validation Accuracy: 64.50%
# Epoch 5, Training Loss: 0.5566, Validation Loss: 0.6515, Validation Accuracy: 67.67%
# Training with avg pooling, None regularization, AdamW optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7132, Validation Loss: 0.6866, Validation Accuracy: 55.83%
# Epoch 2, Training Loss: 0.6332, Validation Loss: 0.6296, Validation Accuracy: 68.67%
# Epoch 3, Training Loss: 0.5639, Validation Loss: 0.7119, Validation Accuracy: 57.33%
# Epoch 4, Training Loss: 0.4805, Validation Loss: 0.7116, Validation Accuracy: 63.50%
# Epoch 5, Training Loss: 0.3693, Validation Loss: 0.8338, Validation Accuracy: 59.50%
# Early stopping triggered at epoch 5.
# Training with avg pooling, None regularization, AdamW optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7208, Validation Loss: 0.6909, Validation Accuracy: 52.17%
# Epoch 2, Training Loss: 0.6849, Validation Loss: 0.6971, Validation Accuracy: 54.33%
# Epoch 3, Training Loss: 0.6702, Validation Loss: 0.6644, Validation Accuracy: 60.33%
# Epoch 4, Training Loss: 0.6265, Validation Loss: 0.6559, Validation Accuracy: 63.50%
# Epoch 5, Training Loss: 0.5772, Validation Loss: 0.6359, Validation Accuracy: 66.00%
# Training with avg pooling, None regularization, AdamW optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7102, Validation Loss: 0.6832, Validation Accuracy: 57.00%
# Epoch 2, Training Loss: 0.6443, Validation Loss: 0.6410, Validation Accuracy: 64.00%
# Epoch 3, Training Loss: 0.5808, Validation Loss: 0.6280, Validation Accuracy: 65.50%
# Epoch 4, Training Loss: 0.5257, Validation Loss: 0.6819, Validation Accuracy: 62.33%
# Epoch 5, Training Loss: 0.4434, Validation Loss: 0.6521, Validation Accuracy: 67.67%
# Training with avg pooling, None regularization, AdamW optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7134, Validation Loss: 0.6704, Validation Accuracy: 58.50%
# Epoch 2, Training Loss: 0.6490, Validation Loss: 0.6487, Validation Accuracy: 64.50%
# Epoch 3, Training Loss: 0.5811, Validation Loss: 0.6273, Validation Accuracy: 64.83%
# Epoch 4, Training Loss: 0.5051, Validation Loss: 0.6252, Validation Accuracy: 67.50%
# Epoch 5, Training Loss: 0.4032, Validation Loss: 0.6468, Validation Accuracy: 66.83%
# Training with avg pooling, None regularization, AdamW optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7048, Validation Loss: 0.6876, Validation Accuracy: 57.83%
# Epoch 2, Training Loss: 0.6335, Validation Loss: 0.6604, Validation Accuracy: 62.67%
# Epoch 3, Training Loss: 0.5785, Validation Loss: 0.6328, Validation Accuracy: 67.50%
# Epoch 4, Training Loss: 0.5133, Validation Loss: 0.6282, Validation Accuracy: 68.17%
# Epoch 5, Training Loss: 0.4373, Validation Loss: 0.6570, Validation Accuracy: 65.50%
# Training with avg pooling, None regularization, AdamW optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7002, Validation Loss: 0.6797, Validation Accuracy: 56.33%
# Epoch 2, Training Loss: 0.6444, Validation Loss: 0.6532, Validation Accuracy: 64.17%
# Epoch 3, Training Loss: 0.5901, Validation Loss: 0.6272, Validation Accuracy: 65.50%
# Epoch 4, Training Loss: 0.5232, Validation Loss: 0.6301, Validation Accuracy: 66.17%
# Epoch 5, Training Loss: 0.4289, Validation Loss: 0.6795, Validation Accuracy: 65.67%
# Training with avg pooling, None regularization, AdamW optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7087, Validation Loss: 0.6911, Validation Accuracy: 54.67%
# Epoch 2, Training Loss: 0.6624, Validation Loss: 0.6928, Validation Accuracy: 58.17%
# Epoch 3, Training Loss: 0.6278, Validation Loss: 0.6729, Validation Accuracy: 65.00%
# Epoch 4, Training Loss: 0.5888, Validation Loss: 0.6336, Validation Accuracy: 66.50%
# Epoch 5, Training Loss: 0.5385, Validation Loss: 0.6527, Validation Accuracy: 64.67%
# Training with avg pooling, None regularization, AdamW optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7140, Validation Loss: 0.6799, Validation Accuracy: 57.83%
# Epoch 2, Training Loss: 0.6627, Validation Loss: 0.6844, Validation Accuracy: 59.17%
# Epoch 3, Training Loss: 0.6224, Validation Loss: 0.6521, Validation Accuracy: 65.00%
# Epoch 4, Training Loss: 0.5875, Validation Loss: 0.6366, Validation Accuracy: 67.00%
# Epoch 5, Training Loss: 0.5543, Validation Loss: 0.6266, Validation Accuracy: 67.83%
# Training with avg pooling, None regularization, SGD optimizer, 0.0 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7008, Validation Loss: 0.6913, Validation Accuracy: 53.00%
# Epoch 2, Training Loss: 0.6988, Validation Loss: 0.6901, Validation Accuracy: 53.33%
# Epoch 3, Training Loss: 0.6975, Validation Loss: 0.6889, Validation Accuracy: 55.83%
# Epoch 4, Training Loss: 0.6962, Validation Loss: 0.6879, Validation Accuracy: 56.67%
# Epoch 5, Training Loss: 0.6946, Validation Loss: 0.6868, Validation Accuracy: 57.67%
# Training with avg pooling, None regularization, SGD optimizer, 0.0 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.6996, Validation Loss: 0.6896, Validation Accuracy: 50.17%
# Epoch 2, Training Loss: 0.6931, Validation Loss: 0.6868, Validation Accuracy: 51.83%
# Epoch 3, Training Loss: 0.6855, Validation Loss: 0.6773, Validation Accuracy: 61.17%
# Epoch 4, Training Loss: 0.6762, Validation Loss: 0.6748, Validation Accuracy: 57.33%
# Epoch 5, Training Loss: 0.6671, Validation Loss: 0.6712, Validation Accuracy: 60.33%
# Training with avg pooling, None regularization, SGD optimizer, 0.25 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7020, Validation Loss: 0.6919, Validation Accuracy: 54.33%
# Epoch 2, Training Loss: 0.6999, Validation Loss: 0.6905, Validation Accuracy: 53.50%
# Epoch 3, Training Loss: 0.6975, Validation Loss: 0.6891, Validation Accuracy: 55.00%
# Epoch 4, Training Loss: 0.6955, Validation Loss: 0.6880, Validation Accuracy: 56.50%
# Epoch 5, Training Loss: 0.6943, Validation Loss: 0.6871, Validation Accuracy: 59.00%
# Training with avg pooling, None regularization, SGD optimizer, 0.25 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7007, Validation Loss: 0.6902, Validation Accuracy: 55.33%
# Epoch 2, Training Loss: 0.6952, Validation Loss: 0.6861, Validation Accuracy: 58.17%
# Epoch 3, Training Loss: 0.6916, Validation Loss: 0.6841, Validation Accuracy: 57.00%
# Epoch 4, Training Loss: 0.6842, Validation Loss: 0.6814, Validation Accuracy: 58.33%
# Epoch 5, Training Loss: 0.6765, Validation Loss: 0.6782, Validation Accuracy: 58.50%
# Training with avg pooling, None regularization, SGD optimizer, 0.5 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7009, Validation Loss: 0.6926, Validation Accuracy: 50.17%
# Epoch 2, Training Loss: 0.7002, Validation Loss: 0.6921, Validation Accuracy: 49.50%
# Epoch 3, Training Loss: 0.6990, Validation Loss: 0.6913, Validation Accuracy: 50.50%
# Epoch 4, Training Loss: 0.6986, Validation Loss: 0.6911, Validation Accuracy: 55.00%
# Epoch 5, Training Loss: 0.6977, Validation Loss: 0.6902, Validation Accuracy: 51.83%
# Training with avg pooling, None regularization, SGD optimizer, 0.5 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7004, Validation Loss: 0.6877, Validation Accuracy: 56.33%
# Epoch 2, Training Loss: 0.6949, Validation Loss: 0.6874, Validation Accuracy: 52.33%
# Epoch 3, Training Loss: 0.6887, Validation Loss: 0.6811, Validation Accuracy: 60.33%
# Epoch 4, Training Loss: 0.6821, Validation Loss: 0.6783, Validation Accuracy: 57.50%
# Epoch 5, Training Loss: 0.6734, Validation Loss: 0.6765, Validation Accuracy: 57.67%
# Training with avg pooling, None regularization, SGD optimizer, 0.75 dropout, 0.0 momentum...
# Epoch 1, Training Loss: 0.7012, Validation Loss: 0.6919, Validation Accuracy: 58.33%
# Epoch 2, Training Loss: 0.7002, Validation Loss: 0.6914, Validation Accuracy: 52.17%
# Epoch 3, Training Loss: 0.6988, Validation Loss: 0.6909, Validation Accuracy: 50.67%
# Epoch 4, Training Loss: 0.6987, Validation Loss: 0.6905, Validation Accuracy: 54.33%
# Epoch 5, Training Loss: 0.6983, Validation Loss: 0.6902, Validation Accuracy: 56.83%
# Training with avg pooling, None regularization, SGD optimizer, 0.75 dropout, 0.9 momentum...
# Epoch 1, Training Loss: 0.7010, Validation Loss: 0.6897, Validation Accuracy: 51.50%
# Epoch 2, Training Loss: 0.6980, Validation Loss: 0.6850, Validation Accuracy: 57.33%
# Epoch 3, Training Loss: 0.6909, Validation Loss: 0.6827, Validation Accuracy: 57.33%
# Epoch 4, Training Loss: 0.6858, Validation Loss: 0.6780, Validation Accuracy: 57.83%
# Epoch 5, Training Loss: 0.6802, Validation Loss: 0.6756, Validation Accuracy: 58.00%

# %% [markdown]
# ## Bonus track

# %%
import timm

resnet_model = timm.create_model('resnet18', pretrained=True, num_classes=2).to(device)
resnet_optimizer = optim.Adam(resnet_model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# Data loading
resnet_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

resnet_train_dataset = datasets.ImageFolder(root="/Users/dmensorio/Desktop/Università Daniele/Third Year/AI506 - Advanced Machine Learning/projects/project 1/catdog_data/train", 
                                    transform=resnet_transform)
resnet_train_loader = DataLoader(resnet_train_dataset, batch_size=32, shuffle=True)

resnet_test_dataset = datasets.ImageFolder(root="/Users/dmensorio/Desktop/Università Daniele/Third Year/AI506 - Advanced Machine Learning/projects/project 1/catdog_data/test", 
                                    transform=resnet_transform)
resnet_test_loader = DataLoader(resnet_test_dataset, batch_size=32, shuffle=False)

resnet_val_dataset = datasets.ImageFolder(root="/Users/dmensorio/Desktop/Università Daniele/Third Year/AI506 - Advanced Machine Learning/projects/project 1/catdog_data/validation", 
                                    transform=resnet_transform)
resnet_val_loader = DataLoader(resnet_val_dataset, batch_size=32, shuffle=False)

# 5. Train and evaluate
print("Training ResNet18..")
train_losses, val_losses, val_acc = train_model(
    resnet_model,
    resnet_train_loader,
    resnet_val_loader,  
    criterion,
    resnet_optimizer,
    epochs=10
)

print(f"\nResNet18 Test Accuracy: {evaluate_model(resnet_model, resnet_test_loader):.2f}%")
# Out:
# Training ResNet18..
# Epoch 1/10, Train Loss: 0.5723, Val Loss: 0.4211, Val Acc: 94.67%
# Epoch 2/10, Train Loss: 0.2988, Val Loss: 0.1840, Val Acc: 96.50%
# Epoch 3/10, Train Loss: 0.1368, Val Loss: 0.1083, Val Acc: 97.17%
# Epoch 4/10, Train Loss: 0.0771, Val Loss: 0.0812, Val Acc: 97.50%
# Epoch 5/10, Train Loss: 0.0465, Val Loss: 0.0684, Val Acc: 97.67%
# Epoch 6/10, Train Loss: 0.0301, Val Loss: 0.0574, Val Acc: 98.17%
# Epoch 7/10, Train Loss: 0.0256, Val Loss: 0.0516, Val Acc: 98.00%
# Epoch 8/10, Train Loss: 0.0220, Val Loss: 0.0513, Val Acc: 98.17%
# Epoch 9/10, Train Loss: 0.0116, Val Loss: 0.0543, Val Acc: 97.83%
# Epoch 10/10, Train Loss: 0.0102, Val Loss: 0.0527, Val Acc: 98.17%
#
# ResNet18 Test Accuracy: 98.75%

# %% [markdown]
# The pretrained ResNet18 model significantly outperforms the custom CNN in terms of training efficiency, validation accuracy, and test accuracy. ResNet18 achieves 98.75% test accuracy, while the custom CNN reaches only 72.00%, indicating better feature extraction and generalization in the pretrained model.
#
# The custom CNN struggles with higher training and validation loss, suggesting limited learning capacity due to its shallower architecture and possible suboptimal hyperparameters. In contrast, ResNet18 shows faster convergence and lower loss, proving the effectiveness of transfer learning for this classification task.
#
# Overall, pretrained deep architectures like ResNet18 offer superior performance compared to training a small CNN from scratch. Improvements to the custom CNN, such as deeper layers, better regularization, and optimized hyperparameters, would be necessary to bridge the performance gap.

# %% [markdown]
# # NOTE
#
# ChatGPT has been employed as a reference tool for the conceptualization and generation of the image plots, serving as a foundational resource in the development of their narrative structure and visual composition.
